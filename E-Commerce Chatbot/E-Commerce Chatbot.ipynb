# %%
import pandas as pd

# Load your Excel file
df = pd.read_excel("Chatbot intents.xlsx")  # Replace with your actual file name

# Normalize text (optional but recommended)
df['Question'] = df['Question'].astype(str).str.lower()
df['Intent'] = df['Intent'].astype(str).str.lower()

# %%
intent_responses = {
        "order_status": "You can check your order status by logging into your account and visiting the 'My Orders' section.",
        "track_order": "To track your order, please use the tracking link provided in your order confirmation email or visit the 'My Orders' page.",
        "return_policy": "Our return policy allows you to return most items within a specified period; please visit our Returns page for full details.",
        "delivery_time": "Delivery typically takes between 3–7 business days, depending on your location and selected shipping method.",
        "shipping_free_offer": "Yes, we offer free shipping on orders above a certain amount; please check our Shipping Policy for more details.",
        "accepted_payment_methods": "We accept credit/debit cards, net banking, UPI, wallets, and other popular payment methods.",
        "cancel_order": "You can cancel your order from the 'My Orders' section before it is shipped, or contact our support team for assistance.",
        "change_delivery_address": "You can change your delivery address before your order is shipped by updating it in your account or contacting support.",
        "contact_support": "You can reach our customer support via email, phone, or live chat; visit our Contact Us page for details.",
        "international_shipping": "Yes, we offer international shipping to select countries; please see our Shipping Policy for availability and rates.",
        "return_sale_items": "Sale items are eligible for return unless otherwise specified in the product description or during the sale.",
        "size_guide_info": "A detailed size guide is available on each product page to help you choose the right fit.",
        "product_authenticity": "All our products are 100% authentic and sourced directly from authorized suppliers or brands.",
        "physical_store_locations": "Yes, we have physical stores; you can find their locations on our Store Locator page.",
        "preorder_items": "We offer pre-order options on select products; look for the 'Pre-order' tag on eligible items.",
        "reset_password": "To reset your password, click 'Forgot Password' on the login page and follow the instructions sent to your email.",
        "forgot_username": "If you forget your username, use the 'Forgot Username' option on the login page or contact support for help.",
        "product_warranty": "Many of our products come with a manufacturer’s warranty; please check the product page for warranty details.",
        "apply_promo_code": "You can apply a promo code during checkout in the 'Promo Code' field before completing your purchase.",
        "support_hours": "Our customer service is available from 9 AM to 8 PM, Monday to Saturday.",
        "payment_upi": "Yes, we accept UPI payments at checkout.",
        "payment_cod": "Cash on delivery is available for select locations and order values; see checkout for eligibility.",
        "payment_declined": "Payments may be declined due to bank issues or incorrect details; please verify your information or try another method.",
        "live_shipment_tracking": "Yes, you can track your shipment live using the tracking link provided after dispatch.",
        "delivery_charges": "Delivery charges vary based on your location and order value; full details are shown at checkout.",
        "exchange_product_option": "Yes, you can exchange eligible products; please refer to our Exchange Policy for more information.",
        "refund_processing_time": "Refunds are typically processed within 5–7 business days after your return is received and inspected.",
        "update_email_address": "To update your email address, go to your account settings and edit your profile information.",
        "change_mobile_number": "You can change your mobile number in your account settings under personal information.",
        "multiple_address_support": "Yes, you can save and manage multiple addresses in your account for faster checkout.",
        "product_installation_service": "We offer installation services for select products; please check the product page or contact support for details.",
        "deactivate_account": "To deactivate your account, please contact our customer support team for assistance.",
        "pause_account": "Currently, we do not offer the option to temporarily pause accounts.",
        "remove_saved_address": "You can remove a saved address by editing your address book in your account settings.",
        "gift_wrap_cost": "Gift wrapping is available at checkout and is free of cost for most orders.",
        "sell_refurbished_items": "We do not sell refurbished items; all our products are brand new and original.",
        "update_profile_picture": "To update your profile picture, go to your account settings and upload a new image.",
        "missing_item_in_order": "If an item is missing from your order, please contact our support team immediately for resolution.",
        "report_damaged_order": "If your order arrives damaged, report it to us with photos within 48 hours for a replacement or refund.",
        "wrong_product_received": "If you received the wrong product, please contact support with your order details for a quick resolution.",
        "request_invoice_copy": "You can download or request an invoice copy from the 'My Orders' section in your account.",
        "product_specifications": "Product specifications are listed on each product page under the 'Details' or 'Specifications' tab.",
        "electronics_certification": "All electronics we sell are certified as per relevant national and international standards.",
        "return_status_tracking": "You can track your return status in the 'My Orders' section or via the return confirmation email.",
        "loyalty_program_info": "Yes, we have a loyalty program that rewards you for shopping with us; learn more on our Loyalty Program page.",
        "earn_reward_points": "You earn reward points on every purchase and through special promotions.",
        "redeem_reward_points": "Reward points can be redeemed at checkout for discounts on future purchases.",
        "reward_points_expiry": "Reward points may expire after a certain period; check your account for details on validity.",
        "loyalty_program_benefits": "Benefits include exclusive discounts, early access to sales, and special rewards.",
        "unsubscribe_emails": "To unsubscribe from emails, click the 'Unsubscribe' link at the bottom of any marketing email.",
        "subscribe_newsletters": "You can subscribe to our newsletter by entering your email in the subscription box on our website.",
        "mobile_app_available": "Yes, we have a mobile app available for both iOS and Android devices.",
        "download_mobile_app": "Download our app from the Apple App Store or Google Play Store by searching our brand name.",
        "mobile_app_free": "Our mobile app is free to download and use.",
        "app_exclusive_deals": "Yes, we offer exclusive deals and discounts on our mobile app.",
        "app_desktop_login": "You can use your desktop login credentials to access your account on the mobile app.",
        "update_mobile_app": "Update the app via the App Store or Google Play Store to ensure you have the latest features.",
        "app_ios_available": "Yes, our app is available for iOS devices on the Apple App Store.",
        "app_android_available": "Yes, our app is available for Android devices on the Google Play Store.",
        "report_app_bug": "You can report app bugs via the feedback option in the app or by contacting our support team.",
        "app_crash_help": "If the app crashes, try restarting it or reinstalling; contact support if the issue persists.",
        "sync_account_devices": "Yes, your account can be synced and accessed across multiple devices.",
        "enable_push_notifications": "Enable push notifications in the app settings to receive updates and offers.",
        "disable_push_notifications": "You can disable push notifications anytime from the app settings.",
        "student_discount_info": "We offer student discounts; check our Student Discount page for eligibility and details.",
        "apply_student_discount": "To apply a student discount, verify your student status during checkout or via our partner platform.",
        "student_discount_documents": "A valid student ID or university email may be required to access student discounts.",
        "first_time_buyer_discount": "Yes, we offer a special discount for first-time buyers; details are available on our homepage or at checkout.",
        "refer_friend": "Refer a friend using your unique referral link found in your account dashboard.",
        "refer_friend_rewards": "You earn rewards or discounts when your referred friend makes their first purchase.",
        "refer_friend_limit": "There is no limit to the number of friends you can refer unless specified in the program terms.",
        "referral_status_check": "Check your referral status and rewards in the 'Referrals' section of your account.",
        "referral_earnings_view": "View your referral earnings or rewards in your account dashboard under 'Referrals' or 'Rewards.'",
        "combine_discount_codes": "Only one discount code can be applied per order unless otherwise specified.",
        "promo_code_not_working": "If your promo code isn’t working, please check the terms and conditions or contact support for help.",
        "report_fake_product": "To report a fake product, contact our support team with details and any supporting evidence.",
        "company_blog_info": "Yes, we have a company blog featuring news, tips, and updates; find it on our website.",
        "follow_social_media": "Follow us on social media via the links at the bottom of our website or search our brand name on your favorite platform.",
        "giveaway_info": "We host regular giveaways; stay tuned to our website and social media for announcements.",
        "next_sale_date": "Our next sale date will be announced soon; subscribe to our newsletter for updates.",
        "festive_discount_info": "Yes, we offer special discounts during major festivals and holidays.",
        "black_friday_sale": "We participate in Black Friday sales with exclusive offers; details will be announced closer to the date.",
        "return_window_duration": "Our standard return window is typically 7–30 days from delivery, depending on the product.",
        "contact_ceo_request": "To contact our CEO, please send your request via our Contact Us form, and it will be forwarded appropriately.",
        "affiliate_program_info": "We offer an affiliate program; visit our Affiliate Program page for more information.",
        "join_affiliate_program": "Sign up for our affiliate program through the registration form on our Affiliate Program page.",
        "affiliate_commission_rates": "Affiliate commission rates vary; detailed information is available on our Affiliate Program page.",
        "affiliate_dashboard_access": "Access your affiliate dashboard by logging into your affiliate account on our website.",
        "affiliate_early_access": "Affiliates may receive early access to select sales and promotions; details are shared via email.",
        "brand_partnership_inquiry": "For brand partnership inquiries, please contact our business development team via our Contact Us page.",
        "influencer_collaboration_info": "We collaborate with influencers; learn more and apply on our Influencer Program page.",
        "join_influencer_program": "Apply to join our influencer program by filling out the application form on our website.",
        "influencer_eligibility": "Eligibility for our influencer program is based on audience size, engagement, and content relevance.",
        "request_free_samples": "You can request free samples for review by contacting our PR team or filling out the request form online.",
        "sponsor_content_creators": "Yes, we sponsor content creators; please reach out with your proposal via our Contact Us page.",
        "company_headquarters_location": "Our headquarters is located at [insert address or city, e.g., Mumbai, India].",
        "company_established_year": "We have been in business since [insert year, e.g., 2012].",
        "company_industries_served": "We serve customers in [insert industries, e.g., fashion, electronics, and home goods].",
        "give_product_feedback": "Share your product feedback via the feedback form on our website or through your order history page.",
        "write_customer_testimonial": "You can write a testimonial on our website’s testimonial section or after completing a purchase.",
        "speak_to_human_support": "Yes, you can request to speak to a real person by calling our support number or using live chat.",
        "live_chat_support": "We offer live chat support on our website and mobile app for instant assistance.",
        "support_response_time": "Our support team typically responds within 24 hours during business days.",
        "weekend_support_availability": "Support is available on weekends during limited hours; please check our Contact Us page for details.",
        "support_languages_available": "We offer support in English and several regional languages; contact us for specific language availability.",
        "request_support_callback": "You can request a callback by filling out the form on our Contact Us page or during your support chat.",
        "support_whatsapp_option": "Yes, you can contact our support team via WhatsApp; the number is listed on our Contact Us page.",
        "support_contact_form": "A contact form is available on our website for submitting queries and feedback.",
        "support_ticket_system": "We use a support ticket system; you’ll receive a ticket number for tracking your request.",
        "escalate_support_ticket": "To escalate an issue, reply to your support ticket or request escalation during your support interaction.",
        "speak_to_support_supervisor": "You can request to speak to a supervisor if you need further assistance with your issue.",
        "phone_support_tollfree": "Our phone support is toll-free; the number is listed on our Contact Us page.",
        "help_center_info": "Our Help Center provides answers to common questions and is available on our website.",
        "faq_section_info": "You can find our FAQs in the dedicated FAQ section on our website.",
         "personalized_recommendation_request": "Yes, you can request a personalized recommendation by sharing your preferences with us via chat or our recommendation form.",
        "chatbot_availability": "Yes, we have a chatbot available 24/7 to assist you with your queries.",    
        "chatbot_functionality": "Our chatbot can help with order tracking, product information, returns, and general support.",
        "delete_account_permanently": "To permanently delete your account, please contact our support team or use the option in your account settings.",
        "recover_deleted_account": "Once an account is permanently deleted, it cannot be recovered.",
        "export_order_history": "You can export your order history from the 'My Orders' section in your account.",
        "financing_options_info": "We offer financing options such as EMI and pay-later services on eligible purchases.",
        "apply_emi_option": "Select the EMI option at checkout and follow the instructions to apply.",
        "emi_terms_conditions": "EMI terms and conditions vary by bank and product; details are available at checkout.",
        "pay_in_installments": "Yes, you can pay in installments on eligible products using our EMI options.",
        "installment_interest_info": "Interest rates for installments depend on your bank and the selected plan.",
        "request_gst_invoice": "Request a GST invoice during checkout or from your order details page.",
        "b2b_order_support": "Yes, we support B2B orders and offer special services for business customers.",
        "place_bulk_order": "To place a bulk order, contact our sales team or use the bulk order form on our website.",
        "bulk_order_discount": "Bulk order discounts are available; please contact us for a custom quote.",
        "hidden_charges_info": "We maintain transparency and do not have hidden charges; all costs are shown at checkout.",
        "check_local_availability": "Enter your pin code on the product page to check availability in your area.",
        "data_privacy_security": "Your personal information is protected with advanced security measures and encryption.",
        "privacy_policy": "You can read our full privacy policy on our website for details on data usage and protection.",
        "cancellation_policy": "Our cancellation policy allows you to cancel orders before they are shipped; see our policy page for details.",
        "order_confirmation_status": "You will receive an order confirmation email and SMS once your order is successfully placed.",
        "reorder_previous_item": "You can reorder previous items from your order history with a single click.",
        "item_stock_check": "Stock status is displayed on each product page; you can also contact support for real-time availability.",
        "write_product_review": "You can write a product review from your order history or the product page after your purchase.",
        "gift_wrap_option": "Gift wrapping is available at checkout; simply select the option before completing your purchase.",
        "same_day_delivery": "Same-day delivery is available in select cities for eligible products.",
        "minimum_order_value": "The minimum order value for delivery is displayed at checkout and may vary by location.",
        "apply_return_request": "Apply for a return from your order details page or by contacting customer support.",
        "change_order_after_placing": "You can request changes to your order before it is shipped by contacting support.",
        "refund_status_check": "Check your refund status in the 'My Orders' section or via the refund confirmation email.",
        "request_express_delivery": "Express delivery can be requested at checkout if available for your location.",
        "courier_service_used": "We use reliable courier partners such as [insert courier names] for delivery.",
         "check_product_genuine": "All our products are sourced from authorized suppliers and are 100% genuine.",
        "track_previous_returns": "You can track all your previous returns in the 'My Orders' section.",
        "order_dispatched_meaning": "'Order dispatched' means your package has left our warehouse and is on its way to you.",
        "website_security_info": "Our website uses SSL encryption and follows best practices to keep your data secure.",
        "schedule_delivery": "You can schedule your delivery date and time during checkout if the option is available.",
        "gift_card_availability": "Yes, we offer gift cards in various denominations for purchase.",
        "use_gift_card": "Enter your gift card code at checkout to redeem its value.",
        "reload_gift_card": "Reloadable gift cards are available; check your gift card balance and reload in your account.",
        "lost_gift_card_help": "If your gift card is lost, contact support with your purchase details for assistance.",
        "custom_product_option": "Some products can be customized; check the product page or contact support for options.",
        "product_engraving_service": "We offer engraving services on select items; details are available on the product page.",
        "warranty_extension_info": "Warranty extension is available for select products at an additional cost.",
        "upgrade_shipping_option": "You can upgrade your shipping method at checkout or by contacting support before dispatch.",
        "eco_friendly_packaging": "We use eco-friendly packaging materials wherever possible.",
        "sustainability_practices": "Our sustainability practices include responsible sourcing, eco-friendly packaging, and waste reduction.",
        "cruelty_free_products": "Yes, we offer a range of cruelty-free products; look for the cruelty-free label on product pages.",
        "vegan_product_availability": "Vegan options are available in select categories; use filters or search for 'vegan' on our website.",
        "delivery_time_slot_selection": "Choose your preferred delivery time slot at checkout if available in your area.",
        "carbon_neutral_shipping": "We offer carbon-neutral shipping options on select orders.",
        "leave_seller_feedback": "Leave seller feedback from your order history or the product page.",
        "buy_now_pay_later_option": "Buy now, pay later options are available at checkout through select payment partners.",
        "expired_promo_code_help": "If your promo code has expired, please check for new offers or contact support for assistance.",
        "pause_subscription": "You can pause your subscription from your account dashboard or by contacting support.",
        "resume_subscription": "Resume your paused subscription anytime from your account dashboard.",
        "skip_delivery_option": "You can skip a scheduled delivery from your subscription management page.",
        "change_subscription_frequency": "Change your subscription frequency in your account settings or subscription management page.",
        "change_subscription_items": "Edit your subscription items from your account dashboard before the next billing cycle.",
        "cancel_subscription": "Cancel your subscription anytime from your account dashboard or by contacting support.",
        "subscription_box_contents": "Your subscription box contents are listed in your account under the subscription section.",
        "corporate_gifting_options": "We offer a variety of corporate gifting options; contact our corporate sales team for details.",
        "custom_corporate_gifts": "Corporate gifts can be personalized with your branding or message; contact us for customization options.",
        "request_sample_before_purchase": "Request a product sample before purchasing by contacting our sales team.",
        "wholesale_pricing_info": "Wholesale pricing is available for bulk orders; contact us for a quote.",
        "contact_vendor_directly": "You can contact the vendor directly through the vendor's profile page or contact form.",
        "vendor_return_policy": "Vendor return policies may vary; please review the policy on the product or vendor page.",
        "locally_made_products": "We support locally made products; look for the 'locally made' tag on product pages.",
        "packaging_material_info": "Our packaging materials are chosen for durability and sustainability.",
        "recyclable_packaging": "Most of our packaging is recyclable; please check the recycling symbol on the package.",
        "remove_payment_method": "Remove a saved payment method from your account settings under payment options.",
        "save_multiple_cards": "Yes, you can save multiple cards in your account for faster checkout.",
        "coupon_not_applying": "If your coupon isn’t applying, please check the terms or contact support for help.",
        "pending_payment_explanation": "'Pending payment' means your payment is being processed or awaiting confirmation.",
        "emi_without_credit_card": "Some EMI options are available without a credit card through select partners.",
        "debit_card_emi": "Yes, we accept EMI payments via select debit cards.",
        "installment_eligibility": "Installment options are available on eligible products; check the product page for details.",
        "auto_renewal_setup": "Set up auto-renewal for subscriptions in your account settings.",
        "disable_auto_renewal": "Disable auto-renewal anytime from your account dashboard.",
        "auto_renewal_policy": "Our auto-renewal policy ensures uninterrupted service; see our policy page for details.",
        "renewal_reminder_info": "We send renewal reminders via email and SMS before your subscription renews.",
        "contact_seller_option": "Contact the seller via the 'Contact Seller' button on the product or order page.",
        "message_seller_feature": "You can send messages to the seller through your order details page.",
        "report_seller_concern": "Report seller concerns using the 'Report Seller' option on the seller's profile or your order page.",
        "unresponsive_seller_help": "If a seller is unresponsive, contact our support team for assistance.",
        "become_seller_process": "Become a seller by registering on our seller portal and submitting the required documents.",
        "seller_requirements": "Seller requirements include valid identification, business details, and compliance with our marketplace policies.",
        "seller_analytics_info": "Sellers have access to analytics and reports from their seller dashboard.",
        "seller_discount_policy": "Sellers can offer discounts on their products as per our platform guidelines.",
        "change_seller_ratings": "Seller ratings can be updated by editing your review within a limited period.",
        "seller_review_reply": "Sellers can reply to customer reviews from their dashboard.",
        "list_products_as_seller": "List new products by logging into your seller account and using the 'Add Product' feature.",
        "edit_product_listing": "Edit your product listings anytime from your seller dashboard.",
        "seller_protection_policy": "Our seller protection policy safeguards sellers against fraud and unfair claims.",
        "seller_listing_fees": "Listing fees, if any, are detailed on our seller portal and vary by category.",
        "seller_product_promotion": "Promote your products using sponsored listings and advertising options in your seller dashboard.",
        "sell_digital_products": "Yes, you can sell digital products on our platform.",
        "upload_digital_products": "Upload digital files from your seller dashboard when listing a digital product.",
        "track_digital_downloads": "Download activity is tracked and viewable in your seller dashboard.",
        "supported_file_formats": "We support a wide range of file formats; see our guidelines for details.",
        "limit_download_access": "You can set download limits for your digital products in the listing settings.",
        "digital_product_protection": "We offer digital product protection features to prevent unauthorized sharing.",
        "set_product_license": "Set licensing terms for your digital products during the listing process.",
        "digital_product_refund_policy": "Digital product refunds are subject to our digital return policy; see the policy page for details.",
        "digital_return_policy": "Our digital return policy outlines the terms for returning or refunding digital products.",
        "digital_order_delivery": "Digital orders are delivered instantly via email or your account downloads section.",
        "instant_download_availability": "Most digital products are available for instant download after purchase.",
        "change_digital_download_email": "Update your email for digital downloads in your account settings.",
        "view_digital_purchases": "View and download your digital purchases from the 'My Downloads' section in your account.",
        "gift_digital_product_option": "You can gift digital products by selecting the 'Gift' option on the product page.",
        "product_tutorials_info": "We offer tutorials and guides for select products; check the product page or our Help Center.",
        "request_product_demo": "Request a product demo by contacting our team or using the demo request form.",
        "book_consultation": "Book a consultation through our website or by contacting our support team.",
        "consultation_fee_info": "Consultation fees vary by service; details are provided during booking.",
        "reschedule_consultation": "Reschedule your consultation from your booking confirmation email or by contacting support.",
        "consultation_no_show_policy": "Our no-show policy is outlined on the booking page; missed appointments may incur a fee.",
        "consultation_recording_info": "Consultations may be recorded for quality purposes with your consent.",
        "prepare_for_consultation": "Prepare for your consultation by reviewing any pre-appointment instructions sent to you.",
        "guest_consultation_policy": "You may bring a guest to your consultation; please inform us in advance.",
        "in_person_consultation_option": "In-person consultations are available at select locations; check availability during booking.",
        "consultation_hours_info": "Consultation hours are listed on our website and vary by service.",
        "consultation_location_info": "Consultations are held at our office or designated locations; details are provided upon booking.",
        "consultation_parking_info": "Parking is available at our consultation venue; please check your confirmation for details.",
        "office_directions_request": "Get directions to our office from the Contact Us page or by using the map link in your confirmation email.",
          "office_accessibility_info": "Yes, our offices are wheelchair accessible with ramps and accessible entrances.",
        "waiting_area_info": "A comfortable waiting area is available for visitors.",
        "consultation_child_policy": "Children are welcome, but please ensure they are supervised during your visit.",
        "office_pet_policy": "Pets are not allowed inside our offices, except for service animals.",
        "visitor_wifi_info": "Guest Wi-Fi is available; please ask our staff for access details.",
        "office_refreshments_availability": "Complimentary refreshments are offered in our waiting area.",
        "store_photo_policy": "You may take photos in our store unless otherwise indicated by signage or staff.",
        "walk_in_policy": "Walk-ins are welcome, but appointments are recommended for faster service.",
        "appointment_requirement_info": "Appointments are not always required, but booking ahead ensures availability.",
        "sms_updates_optin": "You can opt in to receive updates via SMS during checkout or in your account settings.",
        "unsubscribe_sms_updates": "To unsubscribe from SMS updates, reply STOP to any of our messages or update your preferences in your account.",
        "qr_code_payment_availability": "Yes, QR code payments are accepted at our stores and online checkout.",
        "nfc_payment_support": "NFC (contactless) payments are supported at our physical locations.",
        "payment_paypal": "PayPal is accepted as a payment method for online purchases.",
        "payment_confirmation_email": "A payment confirmation email is sent after every successful transaction.",
        "view_payment_history": "View your payment history in your account under 'Transactions' or 'Order History.'",
        "refund_delay_reason": "Refund delays may occur due to bank processing times or incomplete return inspections.",
        "raise_refund_concern": "Raise a refund issue by contacting customer support or submitting a ticket through your account.",
        "split_payment_option": "Currently, splitting payment across two cards is not supported.",
        "purchase_on_credit": "Buy now, pay later and credit options are available for eligible customers at checkout.",
        "zero_interest_emi": "Zero-interest EMI is offered on select products and payment partners.",
        "return_gifted_item": "Gifted items can be returned by the recipient using the order details or gift receipt.",
        "rejected_return_process": "If a return is rejected, the item will be sent back to you with an explanation.",
        "return_tracking_info": "Track your return status in the 'My Orders' section or via the return confirmation email.",
        "cancel_return_request": "You can cancel a return request before it is processed by contacting support.",
        "delivery_signature_required": "Some deliveries require a signature; details are provided at checkout.",
        "alternate_delivery_recipient": "Someone else can receive your order if authorized during checkout or delivery.",
        "delivery_failed_attempts": "After 3 failed delivery attempts, your order will be returned to our warehouse and you will be contacted for further instructions.",
        "reschedule_missed_delivery": "Reschedule a missed delivery by contacting our courier partner or customer support.",
        "delivery_person_location": "Track your delivery person's location using the live tracking link sent after dispatch.",
        "self_pickup_option": "Self-pickup is available at select locations; choose this option at checkout if offered.",
        "delivery_to_locker_option": "Locker delivery is available in select areas; select this option during checkout.",
        "contactless_delivery_info": "Contactless delivery allows you to receive your order with minimal physical interaction.",
        "delivery_vehicle_tracking": "Track the delivery vehicle in real time using the tracking link provided after dispatch.",
        "rate_delivery_experience": "Rate your delivery experience from the order details page or via the feedback link sent after delivery.",
        "delivery_delay_info": "If your delivery is delayed, you will be notified with an updated estimated arrival time.",
        "compensation_for_late_delivery": "Compensation for late delivery may be available; please contact support for eligibility.",
        "delivery_insurance_option": "Delivery insurance is available for select orders at an additional cost.",
        "delivery_claim_process": "File a delivery claim by contacting support with your order and delivery details.",
        "perishable_items_shipping": "We ship perishable items using specialized packaging and expedited delivery.",
        "fragile_items_packaging": "Fragile items are packed with protective materials to ensure safe delivery.",
        "delivery_guarantee_policy": "Our delivery guarantee covers timely delivery or your shipping fee is refunded.",
        "cancel_loyalty_membership": "Cancel your loyalty membership anytime from your account settings or by contacting support.",
        "loyalty_membership_refund": "Loyalty membership fees are non-refundable unless otherwise stated in the terms.",
        "reward_points_for_reviews": "You can earn reward points for writing verified product reviews.",
        "redeem_referral_points": "Redeem your referral points at checkout or from your rewards dashboard.",
        "reward_points_expiry": "Reward points may expire after a set period; check your account for expiry dates.",
        "view_loyalty_tier": "View your current loyalty tier in your account dashboard.",
        "loyalty_program_tiers": "Our loyalty program has multiple tiers, each offering increasing benefits.",
        "downgrade_loyalty_membership": "You can downgrade your membership by contacting customer support.",
        "gold_tier_benefits": "Gold tier benefits include higher reward points, exclusive offers, and priority support.",
        "transfer_loyalty_points": "Loyalty points are non-transferable between accounts.",
        "referral_bonus_timing": "Referral bonuses are credited instantly once your friend completes their first purchase.",
        "social_media_share_rewards": "We reward social media shares with bonus points or exclusive offers during special campaigns.",
        "update_contact_information": "Update your contact information in your account settings.",
        "customer_data_security": "Your data is protected with industry-standard encryption and privacy practices.",
        "delete_user_account": "Delete your account permanently from your account settings or by contacting support.",
        "data_collection_policy": "We collect only necessary data to provide our services; see our privacy policy for details.",
        "website_cookie_usage": "We use cookies to enhance your browsing experience and analyze site traffic.",
        "disable_website_cookies": "Disable cookies from your browser settings or via our cookie preferences tool.",
        "user_data_sale_policy": "We do not sell your personal data to third parties.",
        "unsubscribe_marketing_emails": "Unsubscribe from marketing emails by clicking the link in any email or updating your preferences.",
        "download_user_data": "Download your personal data from your account dashboard or by submitting a request.",
        "request_data_deletion": "Request data deletion by contacting our privacy team or using the online request form.",
        "file_privacy_complaint": "File a privacy complaint by contacting our Data Protection Officer or using our complaint form.",
        "gdpr_compliance_info": "We comply with GDPR and other relevant data protection regulations.",
        "enable_two_factor_auth": "Enable two-factor authentication in your account security settings.",
        "biometric_login_option": "Biometric login is supported on compatible devices through our mobile app.",
        "reset_account_password": "Reset your password by clicking 'Forgot Password' on the login page.",
        "strong_password_criteria": "A strong password should include upper and lower case letters, numbers, and special characters.",
        "enable_login_notifications": "Enable login alerts in your account security settings to receive notifications of new logins.",
        "sso_login_option": "Single sign-on (SSO) is supported for eligible business accounts.",
        "google_login_support": "You can log in using your Google account credentials.",
        "facebook_login_support": "Facebook login is available for quick access to your account.",
        "change_account_username": "Change your username in your account settings or by contacting support.",
        "merge_user_accounts": "Request account merging by contacting customer support with your account details.",
        "forgot_login_email": "If you forgot your login email, contact support for account recovery assistance.",
        "use_multiple_account_emails": "You can add and manage multiple emails in your account settings.",
        "link_phone_number": "Link your phone number to your account in the profile or security settings.",
        "account_lockout_reason": "Account lockouts may occur due to multiple failed login attempts or suspicious activity.",
        "unlock_account_instructions": "Unlock your account by following the instructions sent to your registered email or contacting support.",
        "office_hours_information": "Our office hours are Monday to Friday, 9 AM to 6 PM.",
        "public_holiday_hours": "We are closed on public holidays; holiday hours are posted on our website.",
        "speak_to_live_agent": "You can request to speak to a live agent via phone, chat, or email.",
        "company_email_address": "Our official email address is listed on the Contact Us page.",
        "request_callback_option": "Request a callback by filling out the form on our website or contacting support.",
        "callback_timeframe": "Callbacks are typically made within 24 hours of your request.",
        "company_location_address": "Our office location and address are available on our Contact Us page.",
        "live_chat_availability": "Live chat support is available during business hours on our website and app.",
        "customer_service_number": "Our customer care number is listed on the Contact Us page for immediate assistance.",
        "email_response_time": "We aim to respond to emails within 24 hours during business days.",
        "mobile_app_availability": "Our mobile app is available for download on iOS and Android devices.",
        "ios_app_availability": "Yes, our app is available on the Apple App Store for iOS devices.",
        "android_app_availability": "Yes, our app is available on the Google Play Store for Android devices.",
        "app_only_offers": "Exclusive deals and offers are available only through our mobile app.",
        "report_app_problem": "Report app issues through the app feedback option or by contacting support.",
        "uninstall_app_safely": "You can safely uninstall the app from your device anytime.",
        "enable_dark_mode": "Enable dark mode in the app settings for a comfortable viewing experience.",
        "customize_app_notifications": "Customize notification preferences in your app settings.",
        "clear_mobile_app_cache": "Clear the app cache from your device settings or within the app’s help section.",
        "save_product_favorites": "Save your favorite products by clicking the heart icon on product pages.",
        "app_crash_support": "If the app crashes, restart it or reinstall; contact support if issues persist.",
        "app_usage_tutorial": "An in-app tutorial is available to guide you through the app’s features.",
        "app_offline_mode": "Offline mode allows limited access to certain app features without internet.",
        "app_gesture_support": "The app supports gesture navigation for a smoother experience.",
        "update_app_version": "Update the app from your device’s app store to access the latest features.",
        "wearable_device_support": "Our app supports select wearable devices for notifications and tracking.",
        "enable_voice_search": "Enable voice search in the app settings for hands-free browsing.",
        "ar_preview_feature": "AR preview is available for select products; look for the AR icon on product pages.",
        "personalized_offer_info": "Personalized offers are provided based on your shopping history and preferences.",
        "personalization_method_info": "Personalization is done using your browsing and purchase data to recommend relevant products.",
        "disable_personal_recommendations": "Disable personalized recommendations in your account privacy settings.",
        "ai_based_recommendations": "Yes, we use AI to generate product suggestions tailored to your interests.",
        "view_browsing_history": "View your browsing history in your account dashboard or app settings.",
         "clear_browsing_history": "You can clear your browsing history from your account settings or privacy section.",
        "smart_search_info": "Smart search uses advanced filters and AI to help you quickly find the most relevant products.",
        "price_comparison_feature": "Our platform offers price comparison so you can see the best deals across similar products.",
        "set_price_alerts": "Set price alerts on product pages to get notified when prices drop.",
        "price_update_frequency": "Prices are updated in real-time or several times a day, depending on the product.",
        "price_drop_notifications": "Yes, we notify you via email or app notification when a product on your wishlist drops in price.",
        "share_user_wishlist": "You can share your wishlist with friends and family via a unique link.",
        "create_multiple_wishlists": "Yes, you can create and manage multiple wishlists for different occasions or needs.",
        "move_items_to_wishlist": "Move items to your wishlist from the product page or your cart with a single click.",
        "hide_user_wishlist": "You can set your wishlist to private in the wishlist settings.",
        "wishlist_item_comments": "You can add personal comments to items in your wishlist for your reference.",
        "friend_purchase_from_wishlist": "Friends can purchase items directly from your shared wishlist.",
        "wishlist_collaboration_option": "Collaborative wishlists allow you to invite others to add or edit items.",
        "private_product_collections": "Create private collections to organize products only you can view.",
        "most_viewed_product": "You can see the most viewed products on our trending or popular items page.",
        "top_rated_product_filter": "Filter products by top ratings using the filter options on category pages.",
        "product_color_filter": "Use the color filter on product listings to view items in your preferred color.",
        "price_range_filter": "Filter products by price range using the slider or input fields on the category page.",
        "sort_by_popularity": "Sort products by popularity using the sort dropdown on any product listing page.",
        "save_filter_preferences": "Save your favorite filter settings for faster shopping in your account preferences.",
        "view_similar_products": "View similar products from the product detail page under 'You may also like.'",
        "product_comparison_tool": "Use our product comparison tool to compare features and prices side by side.",
        "view_product_size_chart": "View the size chart on the product page under the 'Size Guide' section.",
        "product_fit_prediction": "Fit prediction uses your profile and past purchases to suggest the best size for you.",
        "customer_uploaded_images": "See customer-uploaded photos in the reviews section of each product page.",
        "verified_review_policy": "We mark reviews from verified buyers to help you trust the feedback.",
        "ask_product_question": "Ask questions about products from the Q&A section on the product detail page.",
        "view_product_qna": "View product questions and answers in the Q&A tab on the product page.",
        "seller_response_to_questions": "Sellers can respond to product questions directly in the Q&A section.",
        "like_customer_review": "Like helpful customer reviews by clicking the thumbs-up icon.",
        "report_fake_reviews": "Report suspicious or fake reviews using the 'Report' option next to the review.",
        "follow_brand_feature": "Follow your favorite brands to get updates on new arrivals and offers.",
        "brand_alert_notifications": "Get alerts from followed brands via email or app notifications.",
        "unfollow_brand_option": "Unfollow a brand anytime from your followed brands list in your account.",
        "influencer_curated_collections": "Browse influencer-curated collections on our special collections page.",
        "student_discount_option": "Apply student discounts at checkout after verifying your student status.",
        "military_discount_availability": "Military discounts are available; verify your status to access special pricing.",
        "combine_discount_policy": "Only one discount or promo code can be applied per order unless otherwise stated.",
        "seasonal_sales_info": "We run seasonal sales throughout the year; check our homepage for current offers.",
        "flash_sale_details": "Flash sales are limited-time events with deep discounts on select products.",
        "next_big_sale_info": "Our next big sale date will be announced soon; subscribe to our newsletter for updates.",
        "early_access_sale_option": "Early access to sales is available for loyalty members and app users.",
        "clearance_items_info": "Clearance items are available in the 'Clearance' section at reduced prices.",
        "back_in_stock_alert_request": "Request a back-in-stock alert on the product page by clicking 'Notify Me.'",
        "restock_notification_method": "Restock updates are sent via email or app notification when an item is available again.",
        "discontinued_item_info": "If an item is discontinued, we will notify you and suggest similar alternatives.",
        "request_item_restock": "Request a restock from the product page; we’ll notify you if it becomes available.",
        "notify_me_feature": "Use the 'Notify Me' button on out-of-stock items to get restock alerts.",
        "preorder_product_option": "Pre-order select products before they are released; look for the pre-order badge.",
        "preorder_shipping_date": "Pre-orders ship on the estimated release date listed on the product page.",
        "cancel_preorder_request": "Cancel a pre-order from your order details or by contacting support before shipment.",
        "preorder_payment_policy": "Pre-orders may require full or partial payment upfront; see product details for specifics.",
        "preorder_refund_policy": "Pre-orders are refundable before shipment as per our pre-order policy.",
        "update_preorder_details": "Update your pre-order details from your account or by contacting support.",
        "estimated_delivery_time_info": "Estimated delivery time is shown at checkout and in your order confirmation.",
        "choose_express_shipping": "Select express shipping at checkout for faster delivery, if available.",
        "international_shipping_availability": "We ship internationally to select countries; see our shipping policy for details.",
        "customs_fee_policy": "Customs fees are not included unless stated; you may be responsible for any import duties.",
        "international_delivery_duration": "International delivery typically takes 7–21 business days, depending on destination.",
        "track_international_shipping": "Track international orders using the tracking link provided after dispatch.",
        "change_delivery_address_after_order": "You can request a delivery address change before shipment by contacting support.",
        "remote_area_delivery_fee": "Remote area delivery may incur additional charges, shown at checkout if applicable.",
        "po_box_delivery_support": "Delivery to P.O. boxes is supported for select items and locations.",
        "sunday_delivery_availability": "Sunday delivery is available in select cities; check at checkout for availability.",
        "eco_friendly_shipping_options": "Eco-friendly shipping options are available at checkout for select orders.",
        "select_packaging_type": "Choose your preferred packaging type at checkout if options are available.",
        "signature_required_for_orders": "Signature is required for high-value or certain orders; details provided at checkout.",
        "delivery_confirmation_request": "You can request delivery confirmation via SMS or email in your order settings.",
        "third_party_courier_info": "We partner with trusted third-party couriers for reliable delivery.",
        "primary_shipping_courier": "Our primary shipping couriers include [insert courier names, e.g., FedEx, DHL, Blue Dart].",
        "contact_shipping_courier": "Contact the courier using the tracking link or customer service number provided in your order details.",
        "invalid_tracking_number_help": "If your tracking number is invalid, please wait for activation or contact support.",
        "item_stuck_in_transit": "If your item is stuck in transit, contact customer support for assistance and an update.",
        "return_instore_online": "In-store purchases can be returned online; initiate the process from your account.",
        "instore_return_timing": "In-store returns are accepted during regular store hours.",
        "instore_return_receipt_policy": "A receipt or proof of purchase is required for all in-store returns.",
        "third_party_return_policy": "Someone else can return your order with the original receipt and authorization.",
        "return_damaged_product": "Return a damaged item by initiating a return request and uploading photos as proof.",
        "return_shipping_cost_policy": "Return shipping is free for eligible returns; details are provided during the return process.",
        "choose_refund_or_credit": "Choose between a refund to your original payment method or store credit during the return process.",
        "refund_destination_info": "Refunds are credited to your original payment method unless you choose store credit.",
        "change_refund_method": "Change your refund method by contacting support before the refund is processed.",
        "refund_failure_resolution": "If your refund fails, contact support to resolve the issue or provide alternative details.",
        "product_repair_services": "We offer repair services for select products; check eligibility on the product page.",
        "request_product_repair": "Request a repair by submitting a service request from your account or contacting support.",
        "track_repair_progress": "Track your repair status in your account under 'Repairs' or via email updates.",
        "product_repair_timeline": "Repairs typically take 7–14 business days, depending on the issue.",
        "product_repair_guarantee": "Repairs are guaranteed for a specified period; see your repair receipt for details.",
        "unrepairable_item_policy": "If repair is not possible, we will offer a replacement or refund as per policy.",
        "warranty_repair_cost_coverage": "Repair costs are covered under warranty for eligible issues within the warranty period.",
        "extended_warranty_availability": "Extended warranties are available for select products at an additional cost.",
        "warranty_claim_process": "Claim warranty service by submitting a request with your purchase details and proof.",
        "check_product_warranty": "Check your product's warranty status in your account or on the product page.",
        "extend_product_warranty": "Extend your warranty from your account or during checkout for eligible products.",
        "accidental_damage_protection": "Accidental damage protection is available for select products as an add-on.",
        "activate_product_warranty": "Activate your warranty by registering your product online after purchase.",
        "view_warranty_policy": "View the full warranty policy on our website or in your account.",
        "transfer_product_warranty": "Warranty transfer is available for select products; contact support for assistance.",
        "international_warranty_validity": "International warranty is available on select products; check product details for coverage.",
        "order_cancellation_fee": "Cancellation fees, if any, are displayed during the cancellation process.",
        "full_refund_on_cancellation": "Full refunds are provided for eligible cancellations before shipment.",
        "cancel_partial_order": "Partial order cancellations are supported for eligible items; manage from your order details.",
        "cancel_service_subscription": "Cancel your subscription from your account dashboard or by contacting support.",
        "subscription_trial_period": "A trial period is available for select subscriptions; see plan details for duration.",
        "pause_service_subscription": "Pause your subscription anytime from your account or by contacting support.",
        "change_subscription_plan": "Change your subscription plan from your account settings or subscription management page.",
        "subscription_auto_renewal": "Subscriptions auto-renew by default; you can disable this in your account settings.",
        "subscription_invoice_request": "Download or request a subscription invoice from your account billing section.",
        "manage_user_subscriptions": "Manage all your subscriptions in your account under 'Subscriptions.'",
        "subscription_cancellation_policy": "Our subscription cancellation policy is available on the plan details page.",
        "subscription_payment_failure": "If your subscription payment fails, you'll be notified to update your payment method.",
        "reactivate_cancelled_subscription": "Reactivate a cancelled subscription from your account or by contacting support.",
        "gift_a_subscription": "Gift a subscription by selecting the 'Gift' option on the subscription page.",
        "subscription_bundle_options": "Bundle options are available for select subscriptions; see the subscription page for details.",
        "corporate_subscription_offers": "Corporate subscription plans are available; contact our sales team for offers.",
        "add_users_to_subscription": "Add members to your subscription plan from your account management page.",
        "family_subscription_plan": "Family plans are available for select services; see plan details for eligibility.",
        "subscription_user_limit": "The maximum number of users per subscription depends on the plan you choose.",
        "upgrade_subscription_storage": "Upgrade your storage space from your account or during plan renewal.",
        "apple_pay_availability": "Apple Pay is accepted for online and in-app purchases.",
        "paypal_payment_option": "PayPal is available as a payment option at checkout.",
        "upi_payment_availability": "UPI payments are supported for online purchases.",
        "split_payment_option": "Currently, split payments across multiple cards are not supported.",
        "emi_payment_availability": "EMI payment options are available for eligible orders at checkout.",
        "use_multiple_payment_methods": "Multiple payment methods per order are not currently supported.",
        "add_payment_card": "Add a new payment card in your account payment settings or during checkout.",
        "remove_saved_payment_card": "Remove a saved card from your account under payment methods.",
        "net_banking_payment_option": "Net banking is available as a payment method at checkout.",
        "payment_gateway_fee_info": "Payment gateway fees, if any, are shown at checkout before you pay.",
        "card_decline_reason": "Card declines may occur due to insufficient funds, incorrect details, or bank restrictions.",
        "retry_failed_payment": "Retry a failed payment from your order page or by updating your payment method.",
        "view_payment_history": "View your full payment history in your account under 'Payments' or 'Orders.'",
        "download_payment_invoice": "Download invoices for your payments from your account or order details page.",
        "set_payment_reminders": "Set payment reminders in your account billing section or app settings.",
        "enable_auto_debit": "Enable auto-debit for subscriptions in your account payment settings.",
        "select_billing_date": "Choose your preferred billing date from your account or during subscription setup.",
        "update_billing_address": "Update your billing address in your account under payment or address settings.",
        "cryptocurrency_payment_option": "Cryptocurrency payments are not currently supported.",
        "cod_availability_check": "Cash on delivery is available for select items and locations.",
        "confirm_cod_order": "Confirm your COD order via SMS or email link sent after placing the order.",
        "cod_fee_information": "A nominal COD fee may apply; details are displayed at checkout.",
        "convert_cod_to_prepaid": "Convert your COD order to prepaid by paying online before delivery.",
        "loyalty_cashback_offer": "Loyalty cashback is credited to your account on eligible purchases.",
        "cashback_credit_method": "Cashback is credited as wallet balance or reward points in your account.",
        "track_cashback_earnings": "Track your cashback earnings in your account rewards or wallet section.",
        "cashback_validity_period": "Cashback validity is displayed in your account; use it before it expires.",
        "combine_cashback_and_coupon": "Cashback and coupons can be combined on select offers; see terms at checkout.",
        "enter_promo_code_location": "Enter your promo code on the checkout page in the 'Promo Code' field.",
        "reuse_promo_code_policy": "Promo codes are generally single-use unless specified otherwise.",
        "promo_code_not_working": "If your promo code isn’t working, check the terms or contact support.",
        "first_time_user_coupon_offer": "First-time user coupons are available; check our homepage or app for details.",
        "referral_coupon_availability": "Referral coupons are offered when you refer friends who make a purchase.",
        "welcome_gift_policy": "Welcome gifts are available for new users on their first purchase.",
        "weekly_contests_info": "We run weekly contests with exciting prizes; check our website or app for details.",
        "participate_in_giveaways": "Participate in giveaways by following our social media or app notifications.",
        "user_engagement_leaderboard": "See the user leaderboard in your account or the rewards section.",
        "earn_daily_loyalty_points": "Earn loyalty points daily by logging in, shopping, or completing activities.",
        "gamified_reward_system": "Play games and complete challenges in our app to earn rewards.",
        "scratch_card_reward_feature": "Scratch cards are available as rewards for select purchases and activities.",
        "view_user_badges": "View your earned badges in your account profile.",
        "user_badge_meaning": "Badges represent achievements and milestones on our platform.",
        "user_profile_level_up": "Level up your profile by earning points, badges, and completing challenges.",
        "invite_friends_option": "Invite friends from your account using your unique referral link.",
        "find_referral_code": "Find your referral code in your account under 'Referrals' or 'Invite Friends.'",
        "friend_invite_limit": "There is no limit to the number of friends you can invite unless specified.",
        "referral_expiry_policy": "Referral codes and bonuses may expire; check your account for details.",
        "resend_referral_invite": "Resend referral invites from your account referral section.",
        "referral_success_tracking": "Track your referral success and rewards in your account dashboard.",
         "referral_milestone_rewards": "Earn milestone rewards for referring multiple friends; see your account for progress.",
        "referral_leaderboard_info": "View the referral leaderboard on our rewards or referral page.",
        "referral_top_reward": "The top referral reward is highlighted on our referral program page.",
        "contact_product_seller": "Contact the seller directly from the product or order details page.",
        "view_seller_ratings": "View seller ratings on the product page or seller profile.",
        "seller_specific_discounts": "Sellers may offer exclusive discounts; look for special offers on product pages.",
        "follow_seller_option": "Follow sellers to get updates on new products and offers.",
        "seller_customer_messaging": "Sellers can message you regarding your orders or queries.",
        "report_seller_option": "Report a seller from their profile or your order page if you encounter issues.",
        "seller_response_time": "Seller response times vary, but most respond within 24 hours.",
        "block_seller_option": "Block a seller from contacting you in your account settings or order page.",
         "favorite_seller_feature": "You can favorite a seller by clicking the heart icon on their profile or product page.",
        "become_platform_seller": "Become a seller by registering on our platform and completing the verification process.",
        "seller_fee_structure": "Seller fees vary by category and include listing, commission, and transaction fees; see our Seller Policy for details.",
        "seller_support_contact": "Seller support is available via dedicated email, chat, or phone; contact details are in your seller dashboard.",
        "list_product_as_seller": "List products for sale from your seller dashboard using the 'Add Product' option.",
        "digital_product_listing_option": "You can offer digital products by selecting the digital category during product listing.",
        "withdraw_seller_earnings": "Withdraw your earnings from the seller dashboard to your linked bank account.",
        "track_seller_sales": "Track your sales and performance from the analytics section in your seller dashboard.",
        "seller_offer_management": "Manage and create discounts for your products in the promotions section of your seller dashboard.",
        "seller_account_verification": "Seller account verification is required for security and to enable payouts.",
        "change_delivery_location_post_order": "Request a delivery location change after ordering by contacting customer support before shipment.",
        "express_delivery_weekend": "Express delivery is available on weekends in select locations.",
        "urgent_delivery_fee": "An extra fee applies for urgent or expedited delivery; details are shown at checkout.",
        "get_tracking_id": "Your tracking ID is available in your order confirmation email and your account's order details.",
        "reason_for_delivery_delay": "Delivery delays may be due to weather, high demand, or courier issues; check your order status for updates.",
        "reschedule_delivery_time": "Reschedule your delivery from your order details page or by contacting support.",
        "contactless_delivery_option": "Contactless delivery is available; select this option at checkout or inform the delivery agent.",
        "change_delivery_date": "Change your delivery date by contacting support before your order is dispatched.",
        "delivery_confirmation_call": "You may receive a confirmation call before delivery, depending on your location and order type.",
        "delivery_person_pre_call": "The delivery person may call you before arriving for delivery.",
        "remote_area_delivery_check": "We deliver to most remote areas; enter your pin code at checkout to confirm.",
        "choose_delivery_time_slot": "Choose your preferred delivery time slot at checkout if the option is available in your area.",
        "missed_delivery_procedure": "If you miss a delivery, our courier will attempt redelivery or contact you for rescheduling.",
        "number_of_delivery_attempts": "We typically make up to three delivery attempts before returning the package to our warehouse.",
        "alternate_person_order_receipt": "Someone else can receive your order if authorized during checkout or delivery.",
        "delivery_signature_required": "A signature may be required for high-value or sensitive deliveries.",
        "leave_delivery_at_door": "You can request to have your delivery left at the door by adding instructions at checkout.",
        "delay_my_shipment": "Delay your shipment by contacting support before your order is dispatched.",
        "change_delivery_instructions": "Change delivery instructions in your order details or by contacting support.",
        "bulk_purchase_discount": "Bulk purchase discounts are available for large orders; contact sales for a quote.",
        "request_large_order_quote": "Request a quote for large orders by filling out the bulk order form or contacting sales.",
        "wholesale_minimum_order_quantity": "The minimum order quantity for wholesale is specified on our wholesale page or by contacting sales.",
        "bulk_pricing_sheet_request": "Request a bulk pricing sheet from our sales team or download it from our website.",
        "b2b_purchase_support": "B2B purchases are supported with special pricing and invoicing options.",
        "corporate_invoice_request": "Request a corporate invoice during checkout or by contacting our billing team.",
        "bulk_order_shipping_policy": "Bulk orders may ship separately or via freight; details are provided during the order process.",
        "bulk_order_contact_support": "Speak to a bulk order manager by contacting our sales or support team.",
        "bulk_return_policy": "Bulk orders are subject to a separate return policy; see our Bulk Returns page for details.",
        "bulk_order_payment_options": "Pay for bulk orders via bank transfer, credit card, or other approved methods.",
        "schedule_recurring_orders": "Schedule recurring orders from your account or by contacting our sales team.",
        "bulk_school_supplies_availability": "Bulk school supplies are available; contact us for catalogs and pricing.",
        "sponsor_a_cause_option": "Sponsor a cause by choosing from our supported charities during checkout.",
        "make_a_donation": "Make a donation at checkout or from our donations page.",
        "donation_drop_off_locations": "Find donation drop-off locations listed on our website or contact support for details.",
        "ngo_collaboration_info": "We collaborate with NGOs for various causes; see our CSR page for partnership details.",
        "donate_reward_points": "Donate your reward points to charity from your rewards dashboard.",
        "get_donation_receipt": "Donation receipts are emailed to you after your contribution.",
        "supported_charitable_causes": "We support education, health, environment, and other charitable causes; see our CSR page for the full list.",
        "round_up_bill_for_charity": "You can round up your bill at checkout to donate the difference to charity.",
        "csr_page_information": "Our CSR page lists our social responsibility initiatives and ongoing projects.",
        "donation_matching_policy": "We match donations during special campaigns; details are announced on our website.",
        "product_return_period": "Our standard return period is 7–30 days from delivery, depending on the product.",
        "return_without_original_box": "Returns without original packaging may be accepted for select items; contact support for guidance.",
        "return_pickup_availability": "Return pickup is available in most locations; schedule it from your order details page.",
        "refund_processing_time": "Refunds are processed within 5–7 business days after the return is received.",
        "return_for_exchange_option": "You can exchange eligible products instead of returning them; see our Exchange Policy.",
        "instant_refund_availability": "Instant refunds are available for select payment methods and return types.",
        "refund_mode_information": "Refunds are issued to your original payment method or as store credit.",
        "track_refund_status": "Track your refund status in your account under 'Orders' or 'Refunds.'",
        "return_fee_information": "Return fees, if any, are displayed during the return process.",
        "submit_customer_complaint": "Submit a complaint via our support form, email, or customer care number.",
        "find_complaint_form": "The complaint form is available on our Contact Us or Help Center page.",
        "complaint_resolution_time": "Complaints are typically resolved within 3–5 business days.",
        "escalate_complaint_procedure": "Escalate your complaint by requesting escalation in your support ticket or contacting a supervisor.",
        "grievance_officer_contact": "Contact our grievance officer via the details provided on our website's grievance redressal page.",
        "give_service_feedback": "Share your service feedback through our feedback form or after order completion.",
        "rate_customer_service": "Rate our customer service from the feedback link sent after support interaction.",
        "customer_feedback_form": "Our feedback form is available on the website and in your account dashboard.",
        "anonymous_feedback_policy": "Feedback can be submitted anonymously if you prefer.",
        "request_call_back": "Request a call back from our support team via the website or app.",
        "update_profile_picture": "Update your profile photo in your account settings.",
        "change_email_address": "Change your email address in your account profile settings.",
        "update_mobile_number": "Update your mobile number in your account settings.",
        "delete_user_account": "Delete your account permanently from your account settings or by contacting support.",
        "manage_account_settings": "Manage all your account settings from your profile dashboard.",
        "two_factor_authentication_option": "Enable 2FA in your account security settings for added protection.",
        "change_user_password": "Change your password in your account security or login settings.",
        "link_social_accounts": "Link your social media accounts from your account settings for easier login.",
        "temporarily_deactivate_account": "Temporarily deactivate your account by contacting support.",
        "app_download_links": "Download our app from the Apple App Store or Google Play Store.",
        "app_available_on_ios": "Yes, our app is available for iOS devices on the App Store.",
        "app_website_cross_use": "You can use the same account on both the app and website.",
        "app_push_notifications_default": "Push notifications are enabled by default; you can change this in app settings.",
        "disable_push_notifications": "Turn off push notifications from your app notification settings.",
        "navigate_app_settings": "Access app settings from the menu or profile section in the app.",
        "app_data_sync_with_web": "Your app data is synced with the website for a seamless experience.",
        "app_crashing_issue": "If the app is crashing, try restarting or reinstalling; contact support if it persists.",
        "report_app_bug": "Report app bugs via the in-app feedback option or contact support.",
        "enable_dark_mode": "Enable dark mode in the app settings for a more comfortable view.",
        "clear_app_cache": "Clear the app cache from your device settings or within the app help section.",
        "logout_from_all_devices": "Log out from all devices from your account security settings.",
        "biometric_login_option": "Biometric login is supported on compatible devices via the app.",
        "change_app_language": "Change the app language in the settings menu.",
        "update_mobile_app": "Update the app from the App Store or Google Play Store.",
        "app_cost_information": "Our app is free to download and use.",
        "app_offline_mode": "Offline mode is available for limited features in the app.",
        "rate_mobile_app": "Rate our app on the App Store or Google Play Store.",
        "new_features_in_app": "See what's new in the app update in the 'What's New' section of the app store listing.",
        "set_user_alerts": "Set up alerts in your account or app notification preferences.",
        "product_alert_follow": "Follow a product for alerts by clicking the bell icon on the product page.",
        "price_drop_notification": "Enable price drop alerts on product pages to get notified of discounts.",
        "manage_alert_preferences": "Manage your alert settings in your account or app notification preferences.",
        "alert_via_sms_option": "You can opt to receive alerts via SMS in your notification settings.",
        "mute_product_alerts": "Mute product notifications from your alert preferences or product page.",
        "view_trending_products": "View trending products on our homepage or in the trending section.",
        "seasonal_sales_info": "We offer seasonal sales throughout the year; check our homepage for current deals.",
         "early_sale_access": "Early access to sales is available for loyalty members and app users.",
        "flash_sale_information": "Flash sales offer limited-time discounts on select products; check our homepage for current events.",
        "todays_best_deals": "Today's best deals are featured on our homepage and deals section.",
        "use_deal_coupon": "Apply a deal coupon at checkout in the 'Promo Code' section.",
        "combine_deals_policy": "Deals and coupons cannot usually be combined unless specified.",
        "location_based_deals": "Some deals are location-based; enter your pin code to see local offers.",
        "personalized_deals_page": "Find personalized deals in your account or app's 'For You' section.",
        "follow_brand_option": "Follow brands from their profile or product pages to get updates.",
        "view_favorite_brands": "View your favorite brands in your account under 'Brands I Follow.'",
        "brand_update_notifications": "Brands you follow can send you updates about new products and offers.",
        "new_brand_showcase": "Discover new brands in our 'New Arrivals' or brand showcase section.",
        "leave_brand_review": "Leave a review for a brand from their profile page.",
        "visit_brand_page": "Visit a brand's page by clicking their name on any product or searching in the brands section.",
        "brand_specific_return_policy": "Brand-specific return policies are listed on the brand or product page.",
        "compare_brands_tool": "Use our compare brands tool to see differences in products, prices, and reviews.",
        "popular_brands_this_week": "Popular brands this week are featured in our trending brands section.",
        "view_brand_ratings": "View brand ratings on their profile or product pages.",
        "brand_giveaway_participation": "Participate in brand giveaways via their page or our promotions section.",
        "sync_wishlist_across_devices": "Your wishlist is synced across all devices when logged into your account.",
        "save_cart_on_mobile": "Your shopping cart is saved on mobile and synced with your account.",
        "share_cart_with_others": "Share your cart with others via a unique link from the cart page.",
        "save_wishlist_requires_account": "Saving a wishlist requires you to have an account and be logged in.",
        "delete_item_from_wishlist": "Delete wishlist items by clicking the remove icon next to each item.",
        "set_priority_in_wishlist": "Set priority for wishlist items by editing their details in your wishlist.",
        "make_wishlist_public": "Make your wishlist public from the privacy settings on the wishlist page.",
        "rename_my_wishlist": "Rename your wishlist by editing its name in the wishlist settings.",
        "add_note_to_wishlist_item": "Add a note to wishlist items from the item details or edit option.",
        "wishlist_item_limit": "There is a limit of 100 items per wishlist.",
        "view_wishlist_price_history": "View price history for wishlist items in the wishlist details section.",
        "copy_wishlist_to_cart": "Copy items from your wishlist to your cart with the 'Move to Cart' option.",
        "share_wishlist_by_link": "Share your wishlist via a unique link from the wishlist page.",
        "auto_delete_wishlist_items": "Wishlist items are not auto-deleted unless the product is discontinued.",
        "wishlist_item_expiry": "Wishlist items do not expire, but availability may change over time.",
        "restock_alerts_wishlist": "Enable restock alerts for wishlist items to get notified when they're back in stock.",
        "move_items_between_wishlists": "Move items between wishlists using the 'Move' option in your wishlist.",
        "wishlist_storage_location": "Your wishlist is securely stored in your account and synced across devices.",
        "sort_my_wishlist": "Sort wishlist items by price, date added, or priority.",
        "product_bundling_feature": "Product bundling is available for select items; look for bundle offers on product pages.",
        "buy_bundle_as_gift": "Buy a bundle as a gift by selecting the gift option at checkout.",
        "bundle_vs_individual_pricing": "Bundles are usually cheaper than buying items individually.",
        "customize_product_bundle": "Customize bundles by selecting your preferred items in the bundle offer.",
        "bundle_discount_eligibility": "Bundles often qualify for additional discounts or promotions.",
        "create_custom_bundle": "Create a custom bundle from the bundle builder page.",
        "partial_bundle_return": "Partial returns are accepted for bundles if specified in the return policy.",
        "bundle_warranty_info": "Bundles include warranty coverage as per the individual product policies.",
        "bundle_gift_wrapping": "Gift wrapping is available for bundles at checkout.",
        "bundle_shipping_policy": "Bundles are shipped together whenever possible for convenience.",
        "cancel_bundle_order": "Cancel a bundle order from your order details page before it is shipped.",
        "track_bundle_order": "Track your bundle order from your account's order tracking section.",
        "pet_supplies_availability": "Pet supplies are available in our dedicated pet section online.",
        "pet_food_online_order": "Order pet food online from our pet supplies section.",
        "subscribe_pet_food_delivery": "Subscribe for regular pet food delivery from the product page.",
        "pet_grooming_items_sale": "We offer a variety of pet grooming items in our pet care section.",
        "return_pet_toys": "Pet toys are returnable within the standard return window if unused.",
        "pet_brands_available": "We carry popular pet brands; browse the pet section for the full list.",
        "aquarium_products_availability": "Aquarium products are available in our pet supplies category.",
        "vet_recommended_products": "Look for the 'Vet Recommended' label on select pet products.",
        "cash_on_delivery_pet_items": "Cash on delivery is available for pet items in eligible locations.",
        "pet_clothing_size_guide": "A size guide for pet clothing is available on each product page.",
        "eco_friendly_pet_products": "Eco-friendly pet products are marked with a green leaf icon.",
        "donate_pet_food": "Donate pet food by selecting the donation option in our pet section.",
        "support_animal_shelters": "We support animal shelters through donations and partnerships.",
        "pet_care_blog_location": "Read our pet care blog in the pet section of our website.",
        "request_free_product_samples": "Request free product samples from our samples page or during checkout.",
        "get_trial_size_product": "Get trial-size products by selecting the trial option on eligible product pages.",
        "free_sample_randomness": "Free samples may be random or based on your order history.",
        "free_sample_limit": "The number of free samples per customer is limited; see the samples page for details.",
        "sample_shipping_fee": "Shipping for samples may be free or charged at a nominal rate.",
        "qualify_for_free_samples": "Qualify for free samples by meeting the minimum order value or through special promotions.",
        "review_free_samples": "Review free samples from your order history or the samples review page.",
        "opt_out_of_samples": "Opt out of receiving samples in your account preferences.",
        "return_free_samples_policy": "Free samples are not returnable.",
        "sample_request_form": "Request samples using the form on our samples page.",
        "availability_diy_kits": "DIY kits are available in our DIY and crafts section.",
        "diy_kit_tutorials": "Watch tutorials for DIY kits on the product page or our YouTube channel.",
        "diy_kit_return_policy": "DIY kits can be returned if unopened and within the return window.",
        "diy_kits_with_tools": "Some DIY kits include all necessary tools; check product details for contents.",
        "diy_kit_kid_safety": "DIY kits safe for kids are marked with an age-appropriate label.",
        "gift_diy_kit": "Gift a DIY kit by selecting the gift option at checkout.",
        "review_diy_kit": "Review DIY kits from your order history or the product page.",
        "diy_home_decor_kits": "DIY home decor kits are available in our DIY section.",
        "diy_subscription_box": "Subscribe to our DIY box for monthly creative projects.",
        "choose_diy_difficulty": "Choose DIY kit difficulty level from the product options.",
        "personalize_diy_kits": "Personalize DIY kits by selecting customization options on the product page.",
        "educational_kits_availability": "Educational kits are available in the learning and toys section.",
        "bulk_order_diy_kits_for_schools": "Bulk order DIY kits for schools by contacting our sales team.",
        "diy_kit_guide_included": "All DIY kits include a step-by-step guide.",
        "eco_friendly_diy_kits": "Eco-friendly DIY kits are available and marked with a green icon.",
        "view_diy_finished_products": "See finished product photos in the gallery on each DIY kit page.",
         "pre_packed_diy_kits": "DIY kits come pre-packed with all necessary materials.",
        "request_color_in_diy_kit": "Request specific colors for your DIY kit by adding a note at checkout.",
        "diy_kit_warranty_info": "Warranty is available on select DIY kits; check product details.",
        "diy_kit_help_support": "Get help with your DIY kit by contacting our support team.",
        "shop_by_occasion": "Shop by occasion using the filters or dedicated sections on our website.",
        "wedding_gift_section": "Find wedding gifts in our special wedding section.",
        "birthday_bundle_options": "Birthday bundles are available in our gifts and occasions section.",
        "set_occasion_reminders": "Set reminders for special occasions in your account or app.",
        "custom_occasion_gifts": "Order custom gifts for occasions by selecting personalization options.",
        "anniversary_deals": "Anniversary deals are featured in our occasions section.",
        "baby_shower_gift_options": "Baby shower gifts are available in our baby and kids section.",
        "festival_packaging_option": "Festival-specific packaging can be selected at checkout for eligible products.",
        "add_gift_note_option": "Add a personal gift note at checkout.",
        "seasonal_gift_guide": "Our seasonal gift guide is available in the gifts section.",
        "filter_by_holiday": "Filter products by holiday using the occasion filter.",
        "greeting_cards_availability": "Greeting cards are available in our gifts and stationery section.",
        "schedule_gift_delivery": "Schedule a gift delivery date at checkout.",
        "same_day_gift_delivery": "Same-day gift delivery is available in select cities.",
        "free_gift_wrapping": "Gift wrapping is free for most gifts; select the option at checkout.",
        "diwali_offers": "Special Diwali offers are featured in our festival deals section.",
        "eid_hamper_options": "Eid hampers are available in our festive gifts section.",
        "find_gifts_under_500": "Find gifts under 500 in our budget gifts section.",
        "trending_gift_section": "Trending gifts are featured in our trending gifts section.",
        "personalized_mugs_sale": "Personalized mugs are available in our gifts and personalization section.",
        "upload_photo_for_personalized_gift": "Upload your photo for personalized gifts during product customization.",
        "name_engraving_option": "Name engraving is available for select products; choose this option at checkout.",
        "customization_time_estimate": "Customizations typically take 2–5 business days before shipping.",
        "preview_personalized_product": "Preview your personalized product before ordering in the customization tool.",
        "personalized_item_return_policy": "Personalized items are not returnable unless defective.",
        "send_digital_greeting_card": "Send a digital greeting card by selecting the e-card option at checkout.",
        "custom_gift_card_value": "Customize your gift card value during purchase.",
        "redeem_gift_card_instructions": "Redeem your gift card at checkout by entering the code.",
        "gift_card_balance_check": "Check your gift card balance in your account or on the gift card page.",
        "resend_e_gift_card": "Resend an e-gift card from your account or by contacting support.",
        "favorite_seller_feature": "You can favorite a seller by clicking the heart icon on their profile or product page.",
        "become_platform_seller": "Become a seller by registering on our platform and completing the verification process.",
        "seller_fee_structure": "Seller fees vary by category and include listing, commission, and transaction fees; see our Seller Policy for details.",
        "seller_support_contact": "Seller support is available via dedicated email, chat, or phone; contact details are in your seller dashboard.",
        "list_product_as_seller": "List products for sale from your seller dashboard using the 'Add Product' option.",
        "digital_product_listing_option": "You can offer digital products by selecting the digital category during product listing.",
        "withdraw_seller_earnings": "Withdraw your earnings from the seller dashboard to your linked bank account.",
        "track_seller_sales": "Track your sales and performance from the analytics section in your seller dashboard.",
        "seller_offer_management": "Manage and create discounts for your products in the promotions section of your seller dashboard.",
        "seller_account_verification": "Seller account verification is required for security and to enable payouts.",
        "change_delivery_location_post_order": "Request a delivery location change after ordering by contacting customer support before shipment.",
        "express_delivery_weekend": "Express delivery is available on weekends in select locations.",
        "urgent_delivery_fee": "An extra fee applies for urgent or expedited delivery; details are shown at checkout.",
        "get_tracking_id": "Your tracking ID is available in your order confirmation email and your account's order details.",
        "reason_for_delivery_delay": "Delivery delays may be due to weather, high demand, or courier issues; check your order status for updates.",
        "reschedule_delivery_time": "Reschedule your delivery from your order details page or by contacting support.",
        "contactless_delivery_option": "Contactless delivery is available; select this option at checkout or inform the delivery agent.",
        "change_delivery_date": "Change your delivery date by contacting support before your order is dispatched.",
        "delivery_confirmation_call": "You may receive a confirmation call before delivery, depending on your location and order type.",
        "delivery_person_pre_call": "The delivery person may call you before arriving for delivery.",
        "remote_area_delivery_check": "We deliver to most remote areas; enter your pin code at checkout to confirm.",
        "choose_delivery_time_slot": "Choose your preferred delivery time slot at checkout if the option is available in your area.",
        "missed_delivery_procedure": "If you miss a delivery, our courier will attempt redelivery or contact you for rescheduling.",
        "number_of_delivery_attempts": "We typically make up to three delivery attempts before returning the package to our warehouse.",
        "alternate_person_order_receipt": "Someone else can receive your order if authorized during checkout or delivery.",
        "delivery_signature_required": "A signature may be required for high-value or sensitive deliveries.",
        "leave_delivery_at_door": "You can request to have your delivery left at the door by adding instructions at checkout.",
        "delay_my_shipment": "Delay your shipment by contacting support before your order is dispatched.",
        "change_delivery_instructions": "Change delivery instructions in your order details or by contacting support.",
        "bulk_purchase_discount": "Bulk purchase discounts are available for large orders; contact sales for a quote.",
        "request_large_order_quote": "Request a quote for large orders by filling out the bulk order form or contacting sales.",
        "wholesale_minimum_order_quantity": "The minimum order quantity for wholesale is specified on our wholesale page or by contacting sales.",
        "bulk_pricing_sheet_request": "Request a bulk pricing sheet from our sales team or download it from our website.",
        "b2b_purchase_support": "B2B purchases are supported with special pricing and invoicing options.",
        "corporate_invoice_request": "Request a corporate invoice during checkout or by contacting our billing team.",
        "bulk_order_shipping_policy": "Bulk orders may ship separately or via freight; details are provided during the order process.",
        "bulk_order_contact_support": "Speak to a bulk order manager by contacting our sales or support team.",
        "bulk_return_policy": "Bulk orders are subject to a separate return policy; see our Bulk Returns page for details.",
        "bulk_order_payment_options": "Pay for bulk orders via bank transfer, credit card, or other approved methods.",
        "schedule_recurring_orders": "Schedule recurring orders from your account or by contacting our sales team.",
        "bulk_school_supplies_availability": "Bulk school supplies are available; contact us for catalogs and pricing.",
        "sponsor_a_cause_option": "Sponsor a cause by choosing from our supported charities during checkout.",
        "make_a_donation": "Make a donation at checkout or from our donations page.",
        "donation_drop_off_locations": "Find donation drop-off locations listed on our website or contact support for details.",
        "ngo_collaboration_info": "We collaborate with NGOs for various causes; see our CSR page for partnership details.",
        "donate_reward_points": "Donate your reward points to charity from your rewards dashboard.",
        "get_donation_receipt": "Donation receipts are emailed to you after your contribution.",
        "supported_charitable_causes": "We support education, health, environment, and other charitable causes; see our CSR page for the full list.",
        "round_up_bill_for_charity": "You can round up your bill at checkout to donate the difference to charity.",
        "csr_page_information": "Our CSR page lists our social responsibility initiatives and ongoing projects.",
        "donation_matching_policy": "We match donations during special campaigns; details are announced on our website.",
        "product_return_period": "Our standard return period is 7–30 days from delivery, depending on the product.",
        "return_without_original_box": "Returns without original packaging may be accepted for select items; contact support for guidance.",
        "return_pickup_availability": "Return pickup is available in most locations; schedule it from your order details page.",
        "refund_processing_time": "Refunds are processed within 5–7 business days after the return is received.",
        "return_for_exchange_option": "You can exchange eligible products instead of returning them; see our Exchange Policy.",
        "instant_refund_availability": "Instant refunds are available for select payment methods and return types.",
        "refund_mode_information": "Refunds are issued to your original payment method or as store credit.",
        "track_refund_status": "Track your refund status in your account under 'Orders' or 'Refunds.'",
        "return_fee_information": "Return fees, if any, are displayed during the return process.",
        "submit_customer_complaint": "Submit a complaint via our support form, email, or customer care number.",
        "find_complaint_form": "The complaint form is available on our Contact Us or Help Center page.",
        "complaint_resolution_time": "Complaints are typically resolved within 3–5 business days.",
        "escalate_complaint_procedure": "Escalate your complaint by requesting escalation in your support ticket or contacting a supervisor.",
        "grievance_officer_contact": "Contact our grievance officer via the details provided on our website's grievance redressal page.",
        "give_service_feedback": "Share your service feedback through our feedback form or after order completion.",
        "rate_customer_service": "Rate our customer service from the feedback link sent after support interaction.",
        "customer_feedback_form": "Our feedback form is available on the website and in your account dashboard.",
        "anonymous_feedback_policy": "Feedback can be submitted anonymously if you prefer.",
        "request_call_back": "Request a call back from our support team via the website or app.",
        "update_profile_picture": "Update your profile photo in your account settings.",
        "change_email_address": "Change your email address in your account profile settings.",
        "update_mobile_number": "Update your mobile number in your account settings.",
        "delete_user_account": "Delete your account permanently from your account settings or by contacting support.",
        "manage_account_settings": "Manage all your account settings from your profile dashboard.",
        "two_factor_authentication_option": "Enable 2FA in your account security settings for added protection.",
        "change_user_password": "Change your password in your account security or login settings.",
        "link_social_accounts": "Link your social media accounts from your account settings for easier login.",
        "temporarily_deactivate_account": "Temporarily deactivate your account by contacting support.",
        "app_download_links": "Download our app from the Apple App Store or Google Play Store.",
        "app_available_on_ios": "Yes, our app is available for iOS devices on the App Store.",
        "app_website_cross_use": "You can use the same account on both the app and website.",
        "app_push_notifications_default": "Push notifications are enabled by default; you can change this in app settings.",
        "disable_push_notifications": "Turn off push notifications from your app notification settings.",
        "navigate_app_settings": "Access app settings from the menu or profile section in the app.",
        "app_data_sync_with_web": "Your app data is synced with the website for a seamless experience.",
        "app_crashing_issue": "If the app is crashing, try restarting or reinstalling; contact support if it persists.",
        "report_app_bug": "Report app bugs via the in-app feedback option or contact support.",
        "enable_dark_mode": "Enable dark mode in the app settings for a more comfortable view.",
        "clear_app_cache": "Clear the app cache from your device settings or within the app help section.",
        "logout_from_all_devices": "Log out from all devices from your account security settings.",
        "biometric_login_option": "Biometric login is supported on compatible devices via the app.",
        "change_app_language": "Change the app language in the settings menu.",
        "update_mobile_app": "Update the app from the App Store or Google Play Store.",
        "app_cost_information": "Our app is free to download and use.",
        "app_offline_mode": "Offline mode is available for limited features in the app.",
        "rate_mobile_app": "Rate our app on the App Store or Google Play Store.",
        "new_features_in_app": "See what's new in the app update in the 'What's New' section of the app store listing.",
        "set_user_alerts": "Set up alerts in your account or app notification preferences.",
        "product_alert_follow": "Follow a product for alerts by clicking the bell icon on the product page.",
        "price_drop_notification": "Enable price drop alerts on product pages to get notified of discounts.",
        "manage_alert_preferences": "Manage your alert settings in your account or app notification preferences.",
        "alert_via_sms_option": "You can opt to receive alerts via SMS in your notification settings.",
        "mute_product_alerts": "Mute product notifications from your alert preferences or product page.",
        "view_trending_products": "View trending products on our homepage or in the trending section.",
        "seasonal_sales_info": "We offer seasonal sales throughout the year; check our homepage for current deals.",
        "early_sale_access": "Early access to sales is available for loyalty members and app users.",
        "flash_sale_information": "Flash sales offer limited-time discounts on select products; check our homepage for current events.",
        "todays_best_deals": "Today's best deals are featured on our homepage and deals section.",
        "use_deal_coupon": "Apply a deal coupon at checkout in the 'Promo Code' section.",
        "combine_deals_policy": "Deals and coupons cannot usually be combined unless specified.",
        "location_based_deals": "Some deals are location-based; enter your pin code to see local offers.",
        "personalized_deals_page": "Find personalized deals in your account or app's 'For You' section.",
        "follow_brand_option": "Follow brands from their profile or product pages to get updates.",
        "view_favorite_brands": "View your favorite brands in your account under 'Brands I Follow.'",
        "brand_update_notifications": "Brands you follow can send you updates about new products and offers.",
        "new_brand_showcase": "Discover new brands in our 'New Arrivals' or brand showcase section.",
        "leave_brand_review": "Leave a review for a brand from their profile page.",
        "visit_brand_page": "Visit a brand's page by clicking their name on any product or searching in the brands section.",
        "brand_specific_return_policy": "Brand-specific return policies are listed on the brand or product page.",
        "compare_brands_tool": "Use our compare brands tool to see differences in products, prices, and reviews.",
        "popular_brands_this_week": "Popular brands this week are featured in our trending brands section.",
        "view_brand_ratings": "View brand ratings on their profile or product pages.",
        "brand_giveaway_participation": "Participate in brand giveaways via their page or our promotions section.",
        "sync_wishlist_across_devices": "Your wishlist is synced across all devices when logged into your account.",
        "save_cart_on_mobile": "Your shopping cart is saved on mobile and synced with your account.",
        "share_cart_with_others": "Share your cart with others via a unique link from the cart page.",
        "save_wishlist_requires_account": "Saving a wishlist requires you to have an account and be logged in.",
        "delete_item_from_wishlist": "Delete wishlist items by clicking the remove icon next to each item.",
        "set_priority_in_wishlist": "Set priority for wishlist items by editing their details in your wishlist.",
        "make_wishlist_public": "Make your wishlist public from the privacy settings on the wishlist page.",
        "rename_my_wishlist": "Rename your wishlist by editing its name in the wishlist settings.",
        "add_note_to_wishlist_item": "Add a note to wishlist items from the item details or edit option.",
        "wishlist_item_limit": "There is a limit of 100 items per wishlist.",
        "view_wishlist_price_history": "View price history for wishlist items in the wishlist details section.",
        "copy_wishlist_to_cart": "Copy items from your wishlist to your cart with the 'Move to Cart' option.",
        "share_wishlist_by_link": "Share your wishlist via a unique link from the wishlist page.",
        "auto_delete_wishlist_items": "Wishlist items are not auto-deleted unless the product is discontinued.",
        "wishlist_item_expiry": "Wishlist items do not expire, but availability may change over time.",
        "restock_alerts_wishlist": "Enable restock alerts for wishlist items to get notified when they're back in stock.",
        "move_items_between_wishlists": "Move items between wishlists using the 'Move' option in your wishlist.",
        "wishlist_storage_location": "Your wishlist is securely stored in your account and synced across devices.",
        "sort_my_wishlist": "Sort wishlist items by price, date added, or priority.",
        "product_bundling_feature": "Product bundling is available for select items; look for bundle offers on product pages.",
        "buy_bundle_as_gift": "Buy a bundle as a gift by selecting the gift option at checkout.",
        "bundle_vs_individual_pricing": "Bundles are usually cheaper than buying items individually.",
        "customize_product_bundle": "Customize bundles by selecting your preferred items in the bundle offer.",
        "bundle_discount_eligibility": "Bundles often qualify for additional discounts or promotions.",
        "create_custom_bundle": "Create a custom bundle from the bundle builder page.",
        "partial_bundle_return": "Partial returns are accepted for bundles if specified in the return policy.",
        "bundle_warranty_info": "Bundles include warranty coverage as per the individual product policies.",
        "bundle_gift_wrapping": "Gift wrapping is available for bundles at checkout.",
        "bundle_shipping_policy": "Bundles are shipped together whenever possible for convenience.",
        "cancel_bundle_order": "Cancel a bundle order from your order details page before it is shipped.",
        "track_bundle_order": "Track your bundle order from your account's order tracking section.",
        "pet_supplies_availability": "Pet supplies are available in our dedicated pet section online.",
        "pet_food_online_order": "Order pet food online from our pet supplies section.",
        "subscribe_pet_food_delivery": "Subscribe for regular pet food delivery from the product page.",
        "pet_grooming_items_sale": "We offer a variety of pet grooming items in our pet care section.",
        "return_pet_toys": "Pet toys are returnable within the standard return window if unused.",
        "pet_brands_available": "We carry popular pet brands; browse the pet section for the full list.",
        "aquarium_products_availability": "Aquarium products are available in our pet supplies category.",
        "vet_recommended_products": "Look for the 'Vet Recommended' label on select pet products.",
        "cash_on_delivery_pet_items": "Cash on delivery is available for pet items in eligible locations.",
        "pet_clothing_size_guide": "A size guide for pet clothing is available on each product page.",
        "eco_friendly_pet_products": "Eco-friendly pet products are marked with a green leaf icon.",
        "donate_pet_food": "Donate pet food by selecting the donation option in our pet section.",
        "support_animal_shelters": "We support animal shelters through donations and partnerships.",
        "pet_care_blog_location": "Read our pet care blog in the pet section of our website.",
        "request_free_product_samples": "Request free product samples from our samples page or during checkout.",
        "get_trial_size_product": "Get trial-size products by selecting the trial option on eligible product pages.",
          "free_sample_randomness": "Free samples may be random or based on your order history.",
        "free_sample_limit": "The number of free samples per customer is limited; see the samples page for details.",
        "sample_shipping_fee": "Shipping for samples may be free or charged at a nominal rate.",
        "qualify_for_free_samples": "Qualify for free samples by meeting the minimum order value or through special promotions.",
        "review_free_samples": "Review free samples from your order history or the samples review page.",
        "opt_out_of_samples": "Opt out of receiving samples in your account preferences.",
        "return_free_samples_policy": "Free samples are not returnable.",
        "sample_request_form": "Request samples using the form on our samples page.",
        "availability_diy_kits": "DIY kits are available in our DIY and crafts section.",
        "diy_kit_tutorials": "Watch tutorials for DIY kits on the product page or our YouTube channel.",
        "diy_kit_return_policy": "DIY kits can be returned if unopened and within the return window.",
        "diy_kits_with_tools": "Some DIY kits include all necessary tools; check product details for contents.",
        "diy_kit_kid_safety": "DIY kits safe for kids are marked with an age-appropriate label.",
        "gift_diy_kit": "Gift a DIY kit by selecting the gift option at checkout.",
        "review_diy_kit": "Review DIY kits from your order history or the product page.",
        "diy_home_decor_kits": "DIY home decor kits are available in our DIY section.",
        "diy_subscription_box": "Subscribe to our DIY box for monthly creative projects.",
        "choose_diy_difficulty": "Choose DIY kit difficulty level from the product options.",
        "personalize_diy_kits": "Personalize DIY kits by selecting customization options on the product page.",
        "educational_kits_availability": "Educational kits are available in the learning and toys section.",
        "bulk_order_diy_kits_for_schools": "Bulk order DIY kits for schools by contacting our sales team.",
        "diy_kit_guide_included": "All DIY kits include a step-by-step guide.",
        "eco_friendly_diy_kits": "Eco-friendly DIY kits are available and marked with a green icon.",
        "view_diy_finished_products": "See finished product photos in the gallery on each DIY kit page.",
        "pre_packed_diy_kits": "DIY kits come pre-packed with all necessary materials.",
        "request_color_in_diy_kit": "Request specific colors for your DIY kit by adding a note at checkout.",
        "diy_kit_warranty_info": "Warranty is available on select DIY kits; check product details.",
        "diy_kit_help_support": "Get help with your DIY kit by contacting our support team.",
        "shop_by_occasion": "Shop by occasion using the filters or dedicated sections on our website.",
        "wedding_gift_section": "Find wedding gifts in our special wedding section.",
        "birthday_bundle_options": "Birthday bundles are available in our gifts and occasions section.",
        "set_occasion_reminders": "Set reminders for special occasions in your account or app.",
        "custom_occasion_gifts": "Order custom gifts for occasions by selecting personalization options.",
        "anniversary_deals": "Anniversary deals are featured in our occasions section.",
        "baby_shower_gift_options": "Baby shower gifts are available in our baby and kids section.",
        "festival_packaging_option": "Festival-specific packaging can be selected at checkout for eligible products.",
        "add_gift_note_option": "Add a personal gift note at checkout.",
        "seasonal_gift_guide": "Our seasonal gift guide is available in the gifts section.",
        "filter_by_holiday": "Filter products by holiday using the occasion filter.",
        "greeting_cards_availability": "Greeting cards are available in our gifts and stationery section.",
        "schedule_gift_delivery": "Schedule a gift delivery date at checkout.",
        "same_day_gift_delivery": "Same-day gift delivery is available in select cities.",
        "free_gift_wrapping": "Gift wrapping is free for most gifts; select the option at checkout.",
        "diwali_offers": "Special Diwali offers are featured in our festival deals section.",
        "eid_hamper_options": "Eid hampers are available in our festive gifts section.",
        "find_gifts_under_500": "Find gifts under 500 in our budget gifts section.",
        "trending_gift_section": "Trending gifts are featured in our trending gifts section.",
        "personalized_mugs_sale": "Personalized mugs are available in our gifts and personalization section.",
        "upload_photo_for_personalized_gift": "Upload your photo for personalized gifts during product customization.",
        "name_engraving_option": "Name engraving is available for select products; choose this option at checkout.",
        "customization_time_estimate": "Customizations typically take 2–5 business days before shipping.",
        "preview_personalized_product": "Preview your personalized product before ordering in the customization tool.",
        "personalized_item_return_policy": "Personalized items are not returnable unless defective.",
        "send_digital_greeting_card": "Send a digital greeting card by selecting the e-card option at checkout.",
        "custom_gift_card_value": "Customize your gift card value during purchase.",
        "redeem_gift_card_instructions": "Redeem your gift card at checkout by entering the code.",
        "gift_card_balance_check": "Check your gift card balance in your account or on the gift card page.",
        "resend_e_gift_card": "Resend an e-gift card from your account or by contacting support.",
      "favorite_seller_feature": "Yes, you can favorite a seller to easily find them later and receive updates about their new products.",
      "become_platform_seller": "To become a seller, sign up for a seller account, complete the required verification, and follow the onboarding steps in your seller dashboard.",
      "seller_fee_structure": "Seller fees may include a commission on each sale, listing fees, and payment processing charges. Check the seller policy page for current rates.",
      "seller_support_contact": "Seller support is available via chat, email, and phone through your seller dashboard or the help center.",
      "list_product_as_seller": "You can list products by logging into your seller account, navigating to 'Add Product', and filling in the required details.",
      "digital_product_listing_option": "Yes, digital products can be listed if you select the appropriate product type during listing.",
      "withdraw_seller_earnings": "Withdraw your earnings by linking your bank account or payment wallet and requesting a payout from your seller dashboard.",
      "track_seller_sales": "Sales can be tracked in real-time from the 'Sales' or 'Orders' section of your seller dashboard.",
      "seller_offer_management": "Sellers can create and manage discounts or promotional offers from the 'Offers' section in their dashboard.",
      "seller_account_verification": "Yes, seller account verification is required to ensure security and compliance.",
      "change_delivery_location_post_order": "Delivery location changes after ordering may be possible before dispatch. Contact support as soon as possible.",
      "express_delivery_weekend": "Express delivery is available on weekends in select locations. Availability will be shown at checkout.",
      "urgent_delivery_fee": "An extra fee may apply for urgent or same-day delivery, depending on your location and order.",
      "get_tracking_id": "Your tracking ID is provided in the order confirmation email and in your account's order details.",
      "reason_for_delivery_delay": "Delays may occur due to weather, high demand, or logistical issues. Check your order status for updates.",
      "reschedule_delivery_time": "You can reschedule delivery through your order page or by contacting customer support before dispatch.",
      "contactless_delivery_option": "Contactless delivery is available. Choose this option during checkout or update your delivery preferences.",
      "change_delivery_date": "You may change your delivery date before dispatch via your account or by contacting support.",
      "delivery_confirmation_call": "A delivery confirmation call may be made before your order arrives, depending on location and courier.",
      "delivery_person_pre_call": "Delivery personnel may call before arriving, especially for high-value or scheduled deliveries.",
      "remote_area_delivery_check": "We deliver to most remote areas. Enter your PIN code at checkout to confirm availability.",
      "choose_delivery_time_slot": "You can choose your preferred delivery time slot during checkout if available for your area.",
      "missed_delivery_procedure": "If you miss a delivery, a new attempt will be scheduled or you will be contacted for instructions.",
      "number_of_delivery_attempts": "Typically, up to 2-3 delivery attempts are made before the order is returned to sender.",
      "alternate_person_order_receipt": "Yes, someone else at your address can receive the order if they provide the necessary information.",
      "delivery_signature_required": "A signature may be required for certain orders, especially high-value items.",
      "leave_delivery_at_door": "You can request to have your order left at the door by updating your delivery instructions.",
      "delay_my_shipment": "Shipment delays can be requested before dispatch by contacting customer support.",
      "change_delivery_instructions": "Change your delivery instructions through your order page or by contacting support before dispatch.",
      "bulk_purchase_discount": "Bulk discounts are available for qualifying orders. Discount details are shown on product or checkout pages.",
      "request_large_order_quote": "You can request a quote for large orders by contacting our sales or bulk order team.",
      "wholesale_minimum_order_quantity": "Minimum order quantities for wholesale vary by product and are listed on the product page.",
      "bulk_pricing_sheet_request": "Bulk pricing sheets can be requested from the sales team or downloaded from the bulk orders section.",
      "b2b_purchase_support": "B2B purchases are supported. Register as a business buyer for additional features and pricing.",
      "corporate_invoice_request": "Corporate invoices are available upon request during or after checkout.",
      "bulk_order_shipping_policy": "Bulk orders may be shipped separately or together depending on size and availability.",
      "bulk_order_contact_support": "Contact our bulk order manager via the bulk orders page or customer support.",
      "bulk_return_policy": "Bulk orders may have a separate return policy. Refer to the bulk order terms or contact support.",
      "bulk_order_payment_options": "Bulk orders can be paid via bank transfer, credit card, or other approved payment methods.",
      "schedule_recurring_orders": "Recurring orders can be scheduled from your account's order management section.",
      "bulk_school_supplies_availability": "School supplies are available in bulk. Browse the bulk section or contact sales for assistance.",
      "sponsor_a_cause_option": "You can sponsor a cause through our platform's charity or CSR section.",
      "make_a_donation": "Donations can be made at checkout or via the dedicated donation page.",
      "donation_drop_off_locations": "Donation drop-off locations are listed on our website under the donations section.",
      "ngo_collaboration_info": "We collaborate with various NGOs. Details are available on our CSR or partnerships page.",
      "donate_reward_points": "Reward points can be donated to select causes via your rewards page.",
      "get_donation_receipt": "Donation receipts are provided by email or available for download from your account.",
      "supported_charitable_causes": "We support a range of causes including education, healthcare, and disaster relief. See our CSR page for details.",
      "round_up_bill_for_charity": "You can round up your bill at checkout to donate the difference to charity.",
      "csr_page_information": "Our CSR page is accessible from the website footer and details our social responsibility initiatives.",
      "donation_matching_policy": "Donation matching may be available during special campaigns. Check the donation page for current offers.",
      "product_return_period": "The standard return period is 7-30 days from delivery, depending on the product.",
      "return_without_original_box": "Returns without original packaging may be accepted for select items. Check the return policy for details.",
      "return_pickup_availability": "Return pickup is available in most locations. Schedule from your order page or contact support.",
      "refund_processing_time": "Refunds are typically processed within 3-7 business days after the return is received.",
      "return_for_exchange_option": "You can request an exchange instead of a refund for eligible products.",
      "instant_refund_availability": "Instant refunds may be available for select payment methods and products.",
      "refund_mode_information": "Refunds are issued to your original payment method or as store credit, as per your choice.",
      "track_refund_status": "Track your refund status from your account's order or returns section.",
      "return_fee_information": "Return fees may apply for certain products or reasons. Details are in the return policy.",
      "submit_customer_complaint": "Submit complaints via the help center, contact form, or customer support hotline.",
      "find_complaint_form": "The complaint form is available in the help center or support section of our website.",
      "complaint_resolution_time": "Complaints are typically resolved within 3-5 business days.",
      "escalate_complaint_procedure": "Escalate complaints by requesting a supervisor or using the escalation option in your complaint ticket.",
      "grievance_officer_contact": "Contact details for the grievance officer are listed in our help center or legal policy page.",
      "give_service_feedback": "Give feedback via post-purchase surveys, the help center, or your account dashboard.",
      "rate_customer_service": "Rate our service through your account, order history, or feedback forms.",
      "customer_feedback_form": "Our feedback form is available in the help center and after each order.",
      "anonymous_feedback_policy": "Feedback can be submitted anonymously unless follow-up is required.",
      "request_call_back": "Request a call back via the support page or by selecting the callback option in the help center.",
       "update_profile_picture": "Update your profile photo from your account settings page.",
      "change_email_address": "Change your email address by editing your profile in account settings.",
      "update_mobile_number": "Update your mobile number from the account settings or profile section.",
      "delete_user_account": "Delete your account by submitting a request through account settings or contacting support.",
      "manage_account_settings": "Manage all account settings from your profile or account dashboard.",
      "two_factor_authentication_option": "Two-factor authentication (2FA) is available for added account security.",
      "change_user_password": "Change your password from the security settings in your account.",
      "link_social_accounts": "Link your social media accounts from the account settings page.",
      "temporarily_deactivate_account": "You can temporarily deactivate your account via the account settings.",
      "app_download_links": "Download the app from the App Store, Google Play, or our website.",
      "app_available_on_ios": "Yes, our app is available for iOS devices in the App Store.",
      "app_website_cross_use": "You can use your account on both the app and website interchangeably.",
      "app_push_notifications_default": "Push notifications are enabled by default but can be managed in app settings.",
      "disable_push_notifications": "Turn off push notifications from the app's notification settings.",
      "navigate_app_settings": "Access app settings from the profile or menu section within the app.",
      "app_data_sync_with_web": "Yes, your data syncs automatically between the app and website when logged in.",
      "app_crashing_issue": "If the app crashes, try updating, clearing cache, or reinstalling. Contact support if the issue persists.",
      "report_app_bug": "Report app bugs via the feedback form or the 'Report a Bug' option in the app.",
      "enable_dark_mode": "Enable dark mode from the app's display or appearance settings.",
      "clear_app_cache": "Clear app cache from the app settings or your device's app management section.",
      "logout_from_all_devices": "Log out from all devices via the security settings in your account.",
      "biometric_login_option": "Biometric login (fingerprint/face ID) is supported on compatible devices.",
      "change_app_language": "Change the app language from the language settings in the app.",
      "update_mobile_app": "Update the app through the App Store, Google Play, or in-app update prompts.",
      "app_cost_information": "The app is free to download and use.",
      "app_offline_mode": "Some features are available offline, but full functionality requires an internet connection.",
      "rate_mobile_app": "Rate the app on the App Store or Google Play.",
      "new_features_in_app": "New features and updates are listed in the app's 'What's New' section or on the update page.",
      "set_user_alerts": "Set up alerts from your account notifications or preferences section.",
      "product_alert_follow": "Follow a product for alerts by selecting the 'Follow' or 'Notify Me' option on the product page.",
      "price_drop_notification": "Enable price drop alerts from the product page or your alert preferences.",
      "manage_alert_preferences": "Manage your alert settings from the notifications or preferences section.",
      "alert_via_sms_option": "SMS alerts are available for select notifications. Enable in your alert preferences.",
      "mute_product_alerts": "Mute product notifications from the alert settings or product page.",
      "view_trending_products": "View trending products on the homepage or the 'Trending' section.",
      "seasonal_sales_info": "Seasonal sales are held during major holidays and events. Check the homepage for announcements.",
      "early_sale_access": "Early access to sales may be available for members or via invitation.",
      "flash_sale_information": "Flash sales are held periodically and are announced on the homepage and through notifications.",
      "todays_best_deals": "Today's best deals are featured on the homepage and deals section.",
      "use_deal_coupon": "Apply a deal coupon at checkout in the promo code field.",
      "combine_deals_policy": "Combining deals may be limited. See the terms and conditions on the deals page.",
      "location_based_deals": "Some deals are location-based and will be shown if eligible for your area.",
      "personalized_deals_page": "Personalized deals are available on your account dashboard or the deals page.",
      "follow_brand_option": "Follow a brand by clicking 'Follow' on the brand's page.",
      "view_favorite_brands": "View your favorite brands in your account's 'Brands' or 'Favorites' section.",
      "brand_update_notifications": "Brands you follow can send you updates about new products and offers.",
      "new_brand_showcase": "New brands are featured in the 'New Arrivals' or 'Brands' section.",
      "leave_brand_review": "Leave a review for a brand from the brand's page or your order history.",
      "visit_brand_page": "Visit a brand's page by clicking their name on a product or searching in the brands section.",
      "brand_specific_return_policy": "Some brands have specific return policies. View these on the brand or product page.",
      "compare_brands_tool": "Compare brands using the comparison tool in the brands section.",
      "popular_brands_this_week": "Popular brands this week are featured on the homepage or brands section.",
      "view_brand_ratings": "View brand ratings on the brand's page or product listings.",
      "brand_giveaway_participation": "Participate in brand giveaways through the brand's page or special promotions.",
      "sync_wishlist_across_devices": "Your wishlist syncs automatically across devices when logged into the same account.",
      "save_cart_on_mobile": "Your shopping cart is saved on mobile when logged in, and syncs with your account.",
      "share_cart_with_others": "Share your cart with others using the 'Share Cart' option in your cart page.",
      "save_wishlist_requires_account": "An account is required to save and sync your wishlist.",
      "delete_item_from_wishlist": "Delete items from your wishlist by selecting 'Remove' next to the item.",
      "set_priority_in_wishlist": "Set priority for wishlist items by editing the item's details in your wishlist.",
      "make_wishlist_public": "You can make your wishlist public from the wishlist settings.",
      "rename_my_wishlist": "Rename your wishlist by selecting 'Edit' on the wishlist page.",
      "add_note_to_wishlist_item": "Add a note to wishlist items by editing the item details.",
      "wishlist_item_limit": "There may be a limit to the number of items in your wishlist. Check the wishlist page for details.",
      "view_wishlist_price_history": "View price history for wishlist items from the item's details page.",
      "copy_wishlist_to_cart": "Copy items from your wishlist to your cart using the 'Move to Cart' option.",
      "share_wishlist_by_link": "Share your wishlist by generating a shareable link from the wishlist page.",
      "auto_delete_wishlist_items": "Wishlist items may be auto-deleted if out of stock or after a certain period.",
      "wishlist_item_expiry": "Wishlist items can expire if not purchased within a set time or if the product is discontinued.",
      "restock_alerts_wishlist": "Enable restock alerts for wishlist items from the item's details or wishlist page.",
      "move_items_between_wishlists": "Move items between wishlists by selecting 'Move' or 'Transfer' on the item.",
      "wishlist_storage_location": "Your wishlist is stored securely in your account and synced to the cloud.",
      "sort_my_wishlist": "Sort your wishlist by price, date added, or priority using the sort options.",
      "product_bundling_feature": "Product bundling is supported. Look for bundle offers on product pages.",
      "buy_bundle_as_gift": "You can purchase a bundle as a gift by selecting the gift option at checkout.",
      "bundle_vs_individual_pricing": "Bundles are often priced lower than purchasing items individually.",
      "customize_product_bundle": "Customize product bundles where available by choosing options on the bundle page.",
      "bundle_discount_eligibility": "Bundles may qualify for additional discounts during promotions.",
      "create_custom_bundle": "Create a custom bundle from the bundle builder tool in the bundles section.",
      "partial_bundle_return": "Partial returns may be accepted for bundles, subject to policy.",
      "bundle_warranty_info": "Warranty on bundles applies as per the included products' policies.",
      "bundle_gift_wrapping": "Gift wrapping is available for bundles at checkout.",
      "bundle_shipping_policy": "Bundles are usually shipped together, but may ship separately if items are from different sellers.",
      "cancel_bundle_order": "Cancel a bundle order from your order page before it is dispatched.",
      "track_bundle_order": "Track your bundle order from the orders section in your account.",
      "pet_supplies_availability": "Pet supplies are available in the pet section of our store.",
      "pet_food_online_order": "Pet food can be ordered online and delivered to your address.",
        "subscribe_pet_food_delivery": "Yes, you can subscribe for regular pet food deliveries by selecting the subscription option on the product page.",
      "pet_grooming_items_sale": "We offer a wide range of pet grooming items in our pet care section.",
      "return_pet_toys": "Pet toys are returnable within the standard return period if they are unused and in original packaging.",
      "pet_brands_available": "We carry popular pet brands such as Pedigree, Royal Canin, Drools, Whiskas, and more. Check the pet brands section for the full list.",
      "aquarium_products_availability": "Yes, we sell aquarium products including tanks, filters, food, and accessories.",
      "vet_recommended_products": "You can find vet-recommended products in our pet health and wellness section.",
      "cash_on_delivery_pet_items": "Cash on delivery is available for most pet items, subject to location and order value.",
      "pet_clothing_size_guide": "A size guide for pet clothes is available on each product page to help you choose the right fit.",
      "eco_friendly_pet_products": "We offer eco-friendly pet products such as biodegradable waste bags and natural treats in our eco section.",
      "donate_pet_food": "You can donate pet food through our donation page or during checkout by selecting a donation option.",
      "support_animal_shelters": "We support animal shelters through donations and partnerships. Details are available on our charity page.",
      "pet_care_blog_location": "Our pet care blog is accessible from the website footer or the pet section for tips and advice.",
      "request_free_product_samples": "You can request free product samples during select promotions or from the samples section.",
      "get_trial_size_product": "Trial sizes are available for select products. Look for the 'trial size' option on the product page.",
      "free_sample_randomness": "Free samples may be random or based on your preferences and order history.",
      "free_sample_limit": "There is a limit to the number of free samples you can receive per order, usually 1-3 items.",
      "sample_shipping_fee": "Shipping for samples is usually free with a qualifying order, but a small fee may apply for standalone sample requests.",
      "qualify_for_free_samples": "You may qualify for free samples by making a purchase, joining our loyalty program, or participating in special campaigns.",
      "review_free_samples": "Review free samples from your order history or the samples feedback page.",
      "opt_out_of_samples": "You can opt out of receiving free samples by updating your preferences in your account settings.",
      "return_free_samples_policy": "Free samples are not returnable.",
      "sample_request_form": "The sample request form is available in the samples section or during eligible promotions.",
      "availability_diy_kits": "DIY kits are available for various crafts, home decor, and educational projects in our DIY section.",
      "diy_kit_tutorials": "Tutorials for DIY kits are available on the product page or our YouTube channel.",
      "diy_kit_return_policy": "DIY kits are returnable within the standard return period if unopened and unused.",
      "diy_kits_with_tools": "Many DIY kits include the necessary tools; check the kit description for details.",
      "diy_kit_kid_safety": "DIY kits safe for kids are clearly marked with age recommendations on the product page.",
      "gift_diy_kit": "You can gift a DIY kit by selecting the gift option at checkout.",
      "review_diy_kit": "Review a DIY kit from your order history or the product review section.",
      "diy_home_decor_kits": "DIY home decor kits are available in the DIY and home decor sections.",
      "diy_subscription_box": "A DIY subscription box is available for monthly project deliveries. Subscribe from the DIY section.",
      "choose_diy_difficulty": "Choose a DIY difficulty level by filtering kits by beginner, intermediate, or advanced on the DIY page.",
      "personalize_diy_kits": "Some DIY kits can be personalized with names or colors. Check the product page for customization options.",
      "educational_kits_availability": "Educational kits for kids and adults are available in our learning section.",
      "bulk_order_diy_kits_for_schools": "Bulk orders for DIY kits for schools can be placed through our bulk order form or by contacting sales.",
      "diy_kit_guide_included": "A step-by-step guide is included with most DIY kits.",
      "eco_friendly_diy_kits": "Eco-friendly DIY kits made with sustainable materials are available in our eco section.",
      "view_diy_finished_products": "View photos of finished DIY projects on the product page or in the community gallery.",
      "pre_packed_diy_kits": "DIY kits come pre-packed with all necessary materials and instructions.",
      "request_color_in_diy_kit": "You can request specific colors for some DIY kits by selecting options on the product page.",
      "diy_kit_warranty_info": "Warranty for DIY kits varies by product. Check the kit description for warranty information.",
      "diy_kit_help_support": "Get assistance with your DIY kit through our help center or by contacting customer support.",
      "shop_by_occasion": "Shop by occasion using filters such as birthday, anniversary, wedding, and more in the gifts section.",
      "wedding_gift_section": "Our wedding gift section features curated gifts for newlyweds and wedding guests.",
      "birthday_bundle_options": "Birthday bundles with themed gifts and packaging are available in the birthday section.",
      "set_occasion_reminders": "Set reminders for special occasions from your account or the occasion reminders page.",
      "custom_occasion_gifts": "Custom gifts for occasions can be created by choosing personalization options on the product page.",
      "anniversary_deals": "Anniversary deals and offers are featured in the anniversary section and during special sales.",
      "baby_shower_gift_options": "Baby shower gifts and bundles are available in the baby section.",
      "festival_packaging_option": "Festival-specific packaging can be selected at checkout for eligible products.",
      "add_gift_note_option": "Add a personalized gift note during checkout.",
      "seasonal_gift_guide": "Our seasonal gift guide is available in the gifts section and updated for each major holiday.",
      "filter_by_holiday": "Filter products by holiday or occasion using the filters on the gifts page.",
      "greeting_cards_availability": "Greeting cards for all occasions are available in the gifts and stationery sections.",
      "schedule_gift_delivery": "Schedule a gift delivery date during checkout for eligible products.",
      "same_day_gift_delivery": "Same-day gift delivery is available in select locations for eligible gifts.",
      "free_gift_wrapping": "Gift wrapping is free for select products and during special promotions.",
      "diwali_offers": "Diwali offers and hampers are featured in the Diwali section during the festival season.",
      "eid_hamper_options": "Eid hampers and gifts are available in the Eid section during the festival period.",
      "find_gifts_under_500": "Find gifts under 500 in the budget gifts section or by using price filters.",
      "trending_gift_section": "Trending gifts are showcased in the trending section of the gifts page.",
      "personalized_mugs_sale": "Personalized mugs are available for sale in the personalized gifts section.",
      "upload_photo_for_personalized_gift": "Upload your own photo for personalized gifts during the customization step on the product page.",
      "name_engraving_option": "Name engraving is available for select products. Choose this option on the product page.",
      "customization_time_estimate": "Customizations typically take 2-5 business days before shipping.",
      "preview_personalized_product": "Preview your personalized product before purchase using the online preview tool.",
      "personalized_item_return_policy": "Personalized items are generally non-returnable unless there is a defect or error.",
      "send_digital_greeting_card": "Send a digital greeting card by selecting the e-card option in the gifts section.",
      "custom_gift_card_value": "You can customize the value of your gift card during purchase.",
      "redeem_gift_card_instructions": "Redeem your gift card by entering the code at checkout or in your account wallet.",
      "gift_card_balance_check": "Check your gift card balance from your account or the gift card balance page.",
      "resend_e_gift_card": "Resend an e-gift card from your account order history or by contacting support.",
      "gift_card_expiry_info": "Gift cards are valid for 6-12 months from the date of purchase, depending on the card.",
      "cancel_gift_card_order": "Cancel a gift card order before it is delivered by contacting customer support.",
      "use_gift_card_on_sale": "Gift cards can be used on sale items unless otherwise specified in the terms.",
      "physical_gift_card_location": "Purchase physical gift cards in-store or from the gift cards section online.",
      "split_payment_gift_card": "Split payment using a gift card and another payment method at checkout.",
      "store_opening_hours": "Store opening hours are listed on our store locator page and may vary by location.",
      "nearest_store_location": "Find your nearest store using the store locator on our website.",
      "store_parking_availability": "Parking availability is listed on each store's information page.",
      "store_wheelchair_accessibility": "Most of our stores are wheelchair accessible. Check the store details page for specific information.",
      "check_local_store_stock": "Check stock at your local store by selecting the store on the product page or calling the store directly.",
      "store_curbside_pickup": "Curbside pickup is available at select locations. Choose this option during checkout.",
      "book_personal_shopper": "Book a personal shopper appointment from our services page or by calling your local store.",
      "store_kids_play_area": "Some stores feature a kids’ play area. Check your local store’s amenities online.",
      "store_fitting_room_availability": "Fitting rooms are available in most stores for trying on apparel.",
      "store_safety_measures": "We follow strict safety measures including sanitization, social distancing, and mask requirements in-store.",
      "in_store_upi_payment": "UPI payments are accepted in-store at checkout counters.",
      "in_store_contactless_payment": "Contactless payment options are available in-store, including NFC cards and mobile wallets.",
      "store_weekend_hours": "Weekend hours are listed on the store locator and may differ from weekday timings.",
      "senior_discount_availability": "Senior citizen discounts are available in-store with valid ID proof.",
      "store_pet_policy": "Pets are welcome in select stores. Check your local store’s policy online.",
      "store_home_delivery_option": "Home delivery from the store is available for most products. Inquire at checkout or with store staff.",
      "store_gift_card_availability": "Gift cards are available for purchase and redemption in-store.",
      "in_store_return_policy": "Items purchased in-store can be returned at any location within the return period with a receipt.",
      "store_exchange_period": "The exchange period for in-store purchases is typically 7-14 days from purchase.",
      "store_product_trial": "You can try select products in-store before buying, depending on product type.",
      "in_store_product_demos": "In-store product demos are available for select electronics and appliances.",
      "store_changing_rooms": "Changing rooms are available in stores selling apparel.",
      "in_store_shopping_assistance": "Shopping assistance is provided by our staff in-store. Ask at the help desk for support.",
      "store_help_desk_location": "The help desk is located near the store entrance or customer service area.",
      "prebook_items_in_store": "Pre-book items for pickup by calling the store or using the online reservation system.",
      "in_store_free_samples": "Free samples are available in-store during special promotions or at select counters.",
      "student_discount_in_store": "Student discounts are available in-store with a valid student ID.",
      "in_store_cod_option": "Cash on delivery is not applicable in-store, but you can pay by cash at checkout.",
      "in_store_product_assembly": "Yes, we offer product assembly services for select items. Please ask a staff member or select assembly at checkout.",
        "store_billing_counter_location": "The billing counter is usually located near the store exit or as indicated by in-store signage.",
      "in_store_digital_wallet_payment": "Digital wallet payments are accepted in-store at checkout counters.",
      "store_loyalty_program": "We offer a loyalty program where you can earn and redeem points on in-store purchases.",
      "redeem_loyalty_points_store": "Redeem loyalty points at checkout by providing your membership details to the cashier.",
      "email_receipt_option": "Receipts can be sent to your email upon request at checkout.",
      "print_invoice_in_store": "A printed invoice is provided for every in-store purchase at the billing counter.",
      "store_restroom_facilities": "Restroom facilities are available for customers in most stores. Please check in-store signage or ask staff for directions.",
      "store_lost_and_found": "Lost and found items are managed at the customer service or help desk in-store.",
      "store_multilingual_staff": "Many stores have staff who speak regional languages to assist you.",
      "store_navigation_map": "Store maps are available at the entrance, information desk, or via our mobile app.",
      "call_retail_store": "You can call the store directly using the contact number listed on our store locator page.",
      "store_price_tax_info": "All price tags in-store are inclusive of applicable taxes unless otherwise stated.",
      "store_price_match_policy": "We offer price matching in-store for identical products from select competitors. Terms and conditions apply.",
      "custom_order_in_store": "Custom orders can be placed in-store for select products by speaking with a sales associate.",
      "gift_wrapping_paper_in_store": "Gift wrapping paper is available for purchase in-store in the stationery or gift section.",
      "in_store_gift_wrapping_service": "Gift wrapping services are available in-store for a small fee or free during promotions.",
      "in_store_coupon_usage": "You can use valid coupons in-store by presenting them at checkout.",
      "in_store_flash_sales": "Flash sales are held in-store during special events and are announced via in-store signage or alerts.",
      "subscribe_store_alerts": "Subscribe to in-store alerts via SMS, email, or our mobile app.",
      "store_bulk_discount": "Bulk purchase discounts are available in-store for qualifying quantities. Ask staff for details.",
      "store_business_account_info": "Business accounts can be set up in-store for corporate or bulk buyers. Inquire at the customer service desk.",
      "store_corporate_billing": "Separate billing for corporate clients is available in-store. Provide your company details at checkout.",
      "in_store_offer_app": "Our mobile app features exclusive in-store offers and notifications.",
      "store_membership_card_usage": "Membership cards can be used in-store to earn and redeem points and access member benefits.",
      "store_damaged_item_return": "Return damaged items to the customer service desk or returns counter in-store.",
      "in_store_carry_bag_availability": "Carry bags are available at checkout for your convenience.",
      "store_eco_friendly_bags": "Eco-friendly and reusable bags are available for purchase at checkout.",
      "store_bag_charge_policy": "A nominal charge may apply for carry bags, as per local regulations.",
      "store_donation_program": "You can donate used items in-store at designated donation bins or counters.",
      "store_recycling_program": "We offer packaging recycling in-store. Ask staff for the recycling drop-off point.",
      "store_customer_waiting_area": "A customer waiting area is available in most stores near the entrance or billing counter.",
      "store_temperature_control": "All stores are equipped with temperature control for customer comfort.",
      "store_hygiene_protocols": "We follow strict hygiene protocols including regular sanitization, mask requirements, and hand sanitizer availability.",
      "in_store_clearance_sale": "Clearance sales are held in-store on select items and are clearly marked.",
      "trial_room_location": "Trial rooms are located in the apparel section. Look for signage or ask staff for directions.",
      "store_valet_parking": "Valet parking is available at select store locations. Check the store details page for availability.",
      "store_emi_payment_option": "EMI payment options are available in-store for eligible purchases. Ask at checkout for details.",
      "in_store_credit_card_payment": "Credit card payments are accepted at all in-store checkout counters.",
      "store_cafeteria_availability": "Some stores have an in-house cafeteria or food court. Check your local store’s amenities.",
      "store_elevator_escalator_info": "Elevators and escalators are available in multi-level stores for customer convenience.",
      "cancel_store_pickup": "You can cancel an in-store pickup order by contacting the store or via your account online.",
      "store_prepaid_card_availability": "Prepaid cards are available for purchase and use in-store.",
      "in_store_gift_suggestions": "Our staff can provide personalized gift suggestions in-store.",
      "in_store_qr_code_scanning": "Scan QR codes in-store to view product details and offers using our mobile app.",
      "store_trial_limit_policy": "There may be a limit to the number of items you can try at once in the trial room. Please ask staff for details.",
      "store_exclusive_products": "Some products are exclusive to our physical stores and not available online.",
      "store_price_protection_policy": "Price protection is offered for select products. If the price drops within a specified period, you may be eligible for a refund of the difference.",
      "register_in_store_complaint": "Register complaints in-store at the customer service desk or via our feedback kiosk.",
      "store_cctv_availability": "CCTV surveillance is active in all stores for your safety and security.",
      "in_store_event_schedule": "Check our event schedule in-store or on our website for upcoming in-store events.",
      "sign_up_store_workshop": "Sign up for workshops in-store at the information desk or via our website.",
      "store_first_aid_availability": "First aid facilities are available in-store. Contact any staff member in case of emergency.",
      "in_store_product_comparison": "Ask staff for product comparisons or use our in-store digital kiosks for detailed information.",
      "in_store_staff_availability": "Floor staff are available at all times during store hours to assist you.",
      "in_store_size_chart_access": "Size charts are available in-store near the apparel section or by asking staff.",
      "store_extended_warranty_option": "Extended warranty can be purchased in-store for eligible products at checkout.",
      "store_suggestion_box": "A suggestion box is available near the customer service desk for your feedback.",
      "store_hand_sanitizer_availability": "Hand sanitizer dispensers are available throughout the store for customer use.",
      "book_store_appointment": "Book a store appointment online or by calling your preferred store.",
      "store_floor_plan_display": "Store floor plans are displayed at the entrance and key locations within the store.",
      "store_sms_alert_subscription": "Subscribe to SMS alerts for in-store offers and events at the customer service desk or via our app.",
      "product_insurance_in_store": "Product insurance is available for select items at the time of purchase in-store.",
      "in_store_barcode_price_check": "Scan product barcodes at self-service kiosks or using our app to check prices in-store.",
      "store_seasonal_decor": "Stores are decorated seasonally for major festivals and events.",
      "in_store_contest_participation": "Participate in in-store contests by registering at the event counter or via our app.",
      "in_store_wifi_availability": "Free Wi-Fi is available for customers in most stores. Ask staff for access details.",
      "in_store_cashback_options": "Cashback offers are available in-store during select promotions. Check with staff or at checkout.",
      "in_store_product_installation": "Product installation services are available for select items. Inquire at checkout or with staff.",
      "apply_promo_code_in_store": "Promo codes can be applied at checkout in-store for eligible offers.",
      "store_bilingual_staff": "Bilingual staff members are available in many stores to assist customers in multiple languages.",
      "store_bridal_registry_service": "Bridal registry services are available in select stores. Ask at the customer service desk for details.",
      "check_instore_item_online": "You can check in-store item availability online via our website or app.",
      "in_store_product_demonstrations": "Product demonstrations are conducted in-store for select items. Check the schedule or ask staff.",
      "store_entrance_sensors": "Store entrances are equipped with sensors for security and automatic doors.",
      "senior_citizen_store_entrance": "Some stores offer a special entrance or priority access for senior citizens. Ask staff for assistance.",
      "fragrance_sampling_in_store": "Fragrance sampling is available in the beauty or personal care section in-store.",
      "store_vs_online_pricing": "Prices may vary between in-store and online due to exclusive offers and promotions.",
      "return_online_order_in_store": "You can return online orders at any of our stores with the original receipt and packaging.",
      "military_discount_in_store": "Military personnel discounts are available in-store with valid ID proof.",
      "refurbished_items_in_store": "Refurbished items are available for purchase in select stores. Check with staff for availability.",
      "express_billing_lane": "Express billing lanes are available in most stores for customers with fewer items.",
      "earn_loyalty_points_in_store": "Earn loyalty points on every in-store purchase by providing your membership details at checkout.",
      "request_sales_associate": "You can request assistance from a sales associate at any time during your store visit.",
      "in_store_pickup_lockers": "Pickup lockers are available in select stores for convenient self-service order collection.",
      "self_checkout_kiosk_availability": "Self-checkout kiosks are available in many stores for faster billing.",
      "bulk_purchase_availability": "Bulk purchases can be made in-store for select products. Ask staff for details and discounts.",
      "use_online_wallet_instore": "You can use your online wallet for in-store purchases at checkout.",
      "store_exit_security_check": "A security check may be conducted at the store exit for your safety.",
      "store_visit_feedback": "Leave feedback about your store visit at the suggestion box, feedback kiosk, or via our app.",
      "store_entrance_sanitizer": "Hand sanitizer is available at the store entrance for all customers.",
      "in_store_price_negotiation": "In-store prices are generally fixed, but negotiation may be possible for bulk or high-value purchases.",
      "preview_clearance_online": "You can preview clearance items online before visiting the store.",
      "festive_sales_in_store": "Festive sales are organized in-store during major holidays and events.",
      "biodegradable_bags_in_store": "Biodegradable carry bags are available for purchase at checkout.",
      "in_store_outfit_suggestions": "Staff can provide outfit suggestions and styling tips in-store.",
      "external_trial_mirrors": "Mirrors are available outside changing rooms in select stores for quick outfit checks.",
      "floor_sample_sale": "Floor samples are occasionally available for sale at discounted prices in-store.",
      "store_staff_product_training": "All staff receive regular product knowledge training to assist you better.",
      "collect_loyalty_rewards_instore": "Loyalty rewards can be collected and redeemed physically at the store during checkout.",
      "in_store_student_promotions": "Special promotions and discounts for students are available in-store with valid student ID.",
      "senior_shopping_hours": "Some stores offer special shopping hours for seniors. Check with your local store for timings.",
      "store_shopping_cart_availability": "Shopping carts and baskets are available at the store entrance for your convenience.",
      "accept_meal_cards_instore": "Sodexo and meal cards are accepted in select stores for eligible purchases.",
       "split_payment_instore": "You can split payments across multiple methods at in-store checkout.",
      "billing_queue_status_monitor": "Queue status displays are available near billing counters in some stores.",
      "store_emergency_assistance": "Emergency assistance is available in-store. Contact any staff member immediately if needed.",
      "in_store_product_launches": "Product launch events are hosted in-store and announced via our website and in-store signage.",
      "change_delivery_address_instore": "You can update your delivery address in-store before your order is processed.",
      "store_ar_experiences": "AR experiences are available in select stores for interactive product exploration.",
      "return_without_receipt_instore": "Returns without a receipt may be accepted at store discretion. Valid ID and product details may be required.",
      "item_exchange_locations": "Item exchanges can be done at any of our store locations, subject to policy.",
      "preorder_collection_instore": "Pre-ordered items can be collected in-store at the designated pickup counter.",
      "shelf_tag_pricing_info": "Prices are printed on shelf tags for all products in-store and are inclusive of applicable taxes.",
       "limited_time_store_deals": "Yes, we regularly offer limited-time in-store deals and promotions. Check in-store signage or our app for current offers.",
      "store_manager_contact": "A store manager is available during operating hours. Please ask any staff member to connect you.",
      "qr_code_purchase_instore": "You can purchase select items by scanning their QR codes in-store using our mobile app.",
      "store_credit_for_returns": "Store credit is offered for eligible returns if you prefer it over a refund.",
      "loyalty_card_multi_location": "Your loyalty card can be used and points redeemed at all our store locations.",
      "sell_extended_warranties_instore": "Extended warranties are available for purchase in-store on eligible products.",
      "display_customer_feedback_instore": "Select customer feedback and reviews may be displayed in-store or on digital screens.",
      "special_shopping_hours_info": "We offer special shopping hours for seniors and vulnerable customers. Check with your local store for timings.",
      "store_cctv_dispute_access": "CCTV footage may be reviewed for dispute resolution, but access is restricted to authorized personnel.",
      "employee_discount_availability": "Employee discounts are available in-store for eligible staff with valid identification.",
      "accept_international_cards": "We accept major international credit and debit cards in-store.",
      "product_instruction_availability": "Product instructions and manuals are available in-store with most products or by request.",
      "report_rude_staff": "You can report a rude staff member at the customer service desk or via our feedback channels.",
      "allergy_friendly_product_instore": "Allergy-friendly products are available in designated sections or can be identified by special labels.",
      "book_service_appointment_instore": "Service appointments can be booked in-store at the customer care booth or via our app.",
      "store_seasonal_contests": "Seasonal contests and giveaways are hosted in-store during festivals and special events.",
      "multilingual_signs_instore": "Multilingual signs are displayed in many stores for easier navigation.",
      "test_electronics_instore": "You can test select electronics in-store at our demo or trial zones.",
      "warranty_info_at_checkout": "Warranty details are shared at checkout and printed on your invoice for eligible products.",
      "aisle_staff_assistance": "Floor staff are available by aisle to assist you with product selection and queries.",
      "store_powercut_support": "Flashlights and emergency lighting are provided during power cuts for customer safety.",
      "store_electronics_insurance": "Insurance for electronics is available for select products at the time of purchase in-store.",
      "accept_digital_gift_vouchers": "Digital gift vouchers are accepted in-store. Present the voucher code at checkout.",
      "loyalty_point_usage_limit": "There may be a daily or per-transaction limit on loyalty point usage. Check your account or ask staff for details.",
      "loyalty_card_replacement_instore": "Replacement loyalty cards can be issued in-store at the customer service desk.",
      "gst_receipt_customization": "GST-compliant receipts can be provided in-store with your business details upon request.",
      "item_restock_alert_instore": "Request restock alerts for out-of-stock items in-store at the customer service desk or via our app.",
      "qr_labeled_items_instore": "Many items in-store are labeled with QR codes for easy scanning and information access.",
      "eco_friendly_section_instore": "Eco-friendly product sections are available in most stores and are clearly marked.",
      "recyclable_shopping_bags": "Recyclable shopping bags are available for purchase at checkout.",
      "prebooking_sale_days": "Pre-booking for popular items is allowed during sale days. Ask staff for details and terms.",
      "live_offers_screens_instore": "Live offers and promotions are displayed on digital screens throughout the store.",
      "take_home_catalogs": "Printed product catalogs are available in-store and can be taken home.",
      "weekend_workshops_instore": "Weekend workshops and demos are organized in-store. Check the event schedule for details.",
      "check_past_purchases_instore": "You can check your past in-store purchases at the customer service desk or via your account.",
      "store_billing_history_availability": "Your in-store billing history is stored and can be accessed with your membership or mobile number.",
      "queue_free_billing_options": "Queue-free billing options such as self-checkout kiosks and express lanes are available in select stores.",
      "gadget_trial_zones_instore": "Gadget trial zones are set up in-store for hands-on experience with electronics.",
      "customer_care_booth_instore": "A customer care booth is available in-store for assistance, queries, and service requests.",
      "in_store_order_tracking": "Track your in-store orders or pickups at the customer care booth or via our app.",
      "walkin_appointment_slots": "Walk-in appointment slots are available for select services. Check with the customer care desk.",
      "biometric_login_instore": "Biometric login is supported at select self-service kiosks for secure access to your account.",
      "handsfree_shopping_instore": "Hands-free shopping assistance is available in select stores. Ask staff for details.",
      "scan_and_go_checkout": "Scan-and-go checkout is available in select stores via our mobile app for faster shopping.",
      "senior_citizen_trolley_support": "Special trolleys are available for senior citizens to make shopping easier.",
      "store_mobile_scanner_app": "Our mobile scanner app lets you scan products in-store for details and self-checkout.",
      "sms_invoice_request": "You can request an invoice by SMS at checkout. Provide your mobile number to receive it instantly.",
      "multilingual_customer_desk": "Customer service desks with multilingual support are available in many stores.",
      "used_openbox_items_instore": "Used and open-box items are available for sale in select stores, clearly labeled and discounted.",
      "in_store_budget_filter": "Set a budget filter for shopping using our app or in-store digital kiosks.",
      "frequent_shopper_tracking": "Frequent shopper visits are tracked via your loyalty account for exclusive rewards.",
      "in_store_gift_wrapping": "Gift-wrapping is available for in-store purchases at the gift desk or checkout.",
      "in_store_barcode_price_scan": "Scan barcodes in-store using our app or self-service kiosks to check prices instantly.",
      "seasonal_decorations_sale": "Seasonal decorations are available for sale in-store during festive periods.",
      "in_store_reserve_for_pickup": "Reserve items in-store for later pickup by speaking with a sales associate.",
      "bulk_purchase_discounts": "Discounts for bulk purchases are available in-store. Ask staff for eligibility and rates.",
      "store_valet_parking": "Valet parking is available at select store locations for customer convenience.",
      "upi_payments_instore": "UPI payments are accepted at all in-store checkout counters.",
      "pet_friendly_store": "Many of our stores are pet-friendly, but policies may vary by location. Please check with your local store before visiting with pets.",
      "personalized_shopping_assistance": "Personalized shopping assistance is available in-store. Ask at the help desk or book in advance.",
      "customizable_products_instore": "We offer customizable products in-store, including gifts, apparel, and accessories. Look for customization signs or ask staff.",
      "schedule_personal_shopper": "You can schedule a personal shopper session by booking online or at the customer service desk.",
      "in_store_student_discount": "Student discounts are available in-store with valid student ID. Ask at checkout for current offers.",
      "in_store_product_recycling": "Product recycling bins are available in-store for select items like electronics and batteries.",
      "store_lost_and_found": "Lost and found services are managed at the customer service desk in all stores.",
      "cart_scanning_checkout": "Scan your cart for faster checkout using our app or self-checkout kiosks in select stores.",
      "kids_play_area_instore": "A kids play area is available in select stores. Check with your local store for availability.",
      "smart_carts_availability": "Smart carts are available in select stores to help you shop and check out faster.",
      "weekend_events_for_customers": "Weekend events and workshops are hosted regularly for customers. Check our events calendar or ask staff.",
      "receipt_customization_options": "Receipt details such as GST, company name, or email can be customized at checkout upon request.",
      "live_cooking_demos_instore": "Live cooking demos are held in select stores. Check the event schedule or ask staff for timings.",
      "quick_checkout_counters": "Quick checkout counters are available in most stores for customers with fewer items.",
      "holiday_gift_exchange_policy": "Gifts purchased during holidays can be exchanged in-store within the extended holiday return period.",
      "budget_based_shopping_suggestions": "Ask staff for shopping suggestions based on your budget or use our in-store digital kiosks.",
      "store_mobile_charging_stations": "Mobile charging stations are available in select stores for customer use.",
      "fitting_room_reservation": "You can reserve fitting rooms in advance at select stores or by speaking to a staff member.",
      "limited_edition_products": "Limited edition products are available in-store and are clearly marked or promoted.",
      "in_store_navigation_maps": "Navigation maps are available at the entrance, on kiosks, or via our mobile app for easy in-store navigation.",
      "gender_neutral_trial_rooms": "Gender-neutral trial rooms are available in select stores. Ask staff for directions.",
      "qr_code_product_info": "Scan QR codes on product tags using our app to view detailed product information.",
      "in_store_fashion_consultants": "Fashion consultants are available in-store for personalized style advice. Book at the help desk.",
      "buy_now_pickup_later": "Buy now and pick up later is available for most products. Choose this option at checkout.",
      "shopping_appointments_in_advance": "Shopping appointments can be booked in advance online or at the customer service desk.",
      "interactive_digital_displays": "Interactive digital displays are installed in many stores for product info and shopping assistance.",
      "store_charity_donation_drives": "Charity donation drives are hosted in-store during special campaigns and festivals.",
      "brand_specific_store_sections": "Brand-specific sections are available for popular brands in-store for easy shopping.",
      "in_store_pay_later_options": "Pay Later options are available in-store through select payment partners. Ask at checkout for eligibility.",
      "billing_waiting_area": "A waiting area is provided near billing counters for customer comfort.",
      "fragrance_free_shopping_hours": "Fragrance-free shopping hours are offered in select stores. Check with your local store for schedule.",
      "view_loyalty_points_instore": "View your loyalty points at checkout or by providing your membership details at the help desk.",
      "customer_grievance_desk": "A dedicated customer grievance desk is available in most stores for feedback and issue resolution.",
      "ai_customer_assistants": "AI-based customer assistants are available via kiosks or our app in select stores.",
      "express_checkout_counters": "Express checkout counters are available for customers with a limited number of items.",
      "warranty_status_instore": "Check your product's warranty status at the customer service desk or via your account in-store.",
      "in_store_cod_acceptance": "Cash-on-delivery is not applicable in-store, but you can pay by cash at checkout.",
      "duplicate_invoice_instore": "Duplicate invoices can be issued at the customer service desk upon request.",
      "guided_store_tour": "Guided store tours are available by appointment. Book at the help desk or online.",
      "kids_shopping_guide": "Kids shopping guides and activity booklets are available at the kids section or help desk.",
      "senior_billing_counter": "Dedicated billing counters for senior citizens are available in select stores.",
      "physical_coupon_redemption": "Physical coupons can be redeemed at checkout for eligible offers.",
      "store_medical_kits": "Emergency medical kits are available in-store. Contact any staff member if needed.",
      "international_return_instore": "International purchases can be returned in-store following our global return policy.",
      "customer_locker_facility": "Secure lockers for valuables are available in select stores. Ask at the help desk for access.",
      "floor_wise_billing_zones": "Billing counters are available on each floor in multi-level stores for your convenience.",
      "packaging_assistance_instore": "Staff can assist with packaging your purchases at checkout or the gift desk.",
      "zero_waste_product_sale": "Zero-waste and sustainable products are available in dedicated sections in-store.",
      "dedicated_gift_section": "A dedicated gift section is available in-store with curated gift options for all occasions.",
      "printed_catalog_request": "Printed catalogs can be requested at the customer service desk or picked up at the entrance.",
      "pet_care_section_instore": "Pet-care product zones are available in-store, featuring food, accessories, and toys.",
      "assistance_for_differently_abled": "Staff are trained to assist differently abled customers. Wheelchair access and other support are available.",
      "prebook_festival_collection": "Festival collections can be pre-booked in-store during special preview events or at the help desk.",
      "virtual_mirror_facility": "Virtual mirror facilities are available in select stores for trying on apparel and accessories digitally.",
      "multilingual_audio_announcements": "Audio announcements in multiple languages are played in many stores for customer convenience.",
      "surprise_flash_sales": "Surprise flash sales are held in-store and announced via app notifications or in-store announcements.",
      "loyalty_points_donation": "You can donate your loyalty points to charity at the help desk or via your account in-store.",
      "kids_restrooms_instore": "Kids' restrooms are available in select stores. Ask staff for directions.",
      "live_gift_wrapping_demos": "Live gift wrapping demonstrations are held in-store during special events and holidays.",
      "digital_valet_receipt": "Digital valet receipts are provided via SMS or app notification in stores with valet parking.",
      "makeup_trial_instore": "Makeup trials are available in the beauty section of most stores.",
      "handmade_items_sale": "Handmade and artisanal items are available in select in-store sections.",
      "physical_newsletters_availability": "Physical newsletters can be picked up at the entrance or customer service desk.",
      "fragrance_sample_on_request": "Fragrance samples are available on request at the beauty counter.",
      "in_store_raffle_events": "In-store raffle events are hosted during festivals and special sales.",
      "wheelchair_assistance_instore": "Wheelchair assistance is available at the entrance or by asking any staff member.",
      "in_store_music_by_department": "Background music is played in all departments, tailored to the shopping area.",
      "store_branded_merchandise": "Store-branded merchandise is available for purchase in the gifts or apparel section.",
      "in_store_app_shopping": "You can shop using our store app in-store for a seamless experience and exclusive offers.",
      "rfid_inventory_tracking": "RFID technology is used for inventory management and faster checkout in select stores.",
      "in_store_event_booking": "Book in-store events and workshops at the customer service desk or via our app.",
      "gender_specific_zones_instore": "Gender-specific shopping zones are available for men, women, and kids in apparel sections.",
      "high_value_item_insurance": "Insurance options are available for high-value items at checkout.",
      "pay_with_loyalty_points": "Loyalty points can be used as payment for eligible purchases at checkout.",
      "bulk_buyer_counter": "Special counters for bulk buyers are available in select stores for faster service.",
      "voice_assisted_checkout": "Voice-assisted checkout is available at select self-service kiosks.",
      "rate_shopping_experience": "Rate your in-store shopping experience at the feedback kiosk or via our app.",
      "store_credit_card_availability": "Store credit cards are available. Apply in-store at the finance desk or online.",
      "in_store_stylist_service": "In-store stylist services are available for personalized fashion advice. Book at the fashion desk.",
      "in_store_cafe_availability": "A café or refreshment area is available in select stores for customers.",
      "flash_sale_notifications": "Sign up for flash sale notifications via SMS, app, or at the help desk.",
      "in_store_repair_services": "Repair services for select products are offered in-store. Visit the service desk for details.",
      "daily_item_restocking": "Items are restocked daily to ensure availability, though some products may vary by demand.",
      "product_comparison_assistance": "Staff can help you compare products in-store or use our digital comparison tools.",
      "store_health_wellness_assistance": "Health and wellness advice is available from trained staff or at the wellness counter.",
      "in_store_shoe_trial": "Try on shoes in-store at the footwear section.",
      "same_day_delivery_instore": "Same-day delivery is available for eligible in-store purchases in select locations.",
      "home_organization_items_sale": "Home organization and storage items are available in the home section of our stores.",
      "stock_query_by_phone": "Call your local store to inquire about product stock and availability.",
      "refurbished_electronics_sale": "Refurbished electronics are available in select stores and are clearly labeled.",
      "customer_wifi_access": "Free Wi-Fi is available for customers in most stores. Ask staff for access details.",
      "upcoming_deals_catalog": "Catalogs for upcoming deals and sales are available at the entrance or customer service desk.",
      "weekend_shopping_slot_booking": "Book a shopping slot for weekends online or by calling the store.",
      "second_hand_item_sales": "Second-hand items are available in select stores and are clearly marked.",
      "trial_room_sanitization_policy": "Trial rooms are sanitized regularly throughout the day for your safety.",
      "locate_by_aisle_number": "Use in-store maps or ask staff to locate items by aisle number.",
      "newsletter_subscription_desk": "Subscribe to our newsletter at the dedicated desk or via our app.",
      "sms_stock_alert_optin": "Opt in for SMS stock alerts at the help desk or via your account.",
      "sodexo_card_acceptance": "Sodexo and meal cards are accepted in select stores for eligible purchases.",
      "returns_counter_location": "The returns counter is located near the store exit or customer service area.",
      "contactless_payment_availability": "Contactless payment options are available at all checkout counters.",
      "price_difference_online_instore": "Prices may differ between in-store and online due to exclusive offers and promotions.",
      "in_store_purchase_history": "Access your purchase history in-store at the help desk or via your account.",
      "missing_item_report": "Report missing items from your package at the customer service desk or through our app.",
      "elderly_shopping_assistance": "Special shopping assistance is available for elderly customers. Ask staff for help anytime.",
      "electric_scooter_charging_station": "Electric scooter charging stations are available outside select stores.",
      "small_item_shopping_baskets": "Baskets for small-item shoppers are available at the store entrance.",
      "in_store_einvoice_collection": "Collect your e-invoice in-store at checkout or request it via email/SMS.",
      "store_food_drink_policy": "Food and drink are generally not allowed inside the store for hygiene reasons, except in designated café areas.",
      "item_security_tags": "Anti-theft security tags are attached to items for your safety and theft prevention.",
      "fragrance_free_cosmetic_hours": "Fragrance-free hours in the cosmetic section are available in select stores. Check with staff for timings.",
      "restock_alert_request": "Request an alert for out-of-stock items at the help desk or via our app. You’ll be notified when they’re available.",
      "weekend_product_demos": "Product demos are offered on weekends in many stores. Check the event schedule or ask staff for timings.",
      "returns_dedicated_counter": "Yes, there is a dedicated counter for returns, usually located near the store exit or customer service area.",
      "contact_store_manager": "You can speak to the store manager by requesting assistance at the help desk or customer service counter.",
      "seasonal_membership_card": "Seasonal membership cards are available during special promotions and offer exclusive benefits for a limited period.",
      "festive_hamper_sales": "Festive hampers are available for sale in-store during major festivals and holidays.",
      "gift_suggestion_request": "Ask any staff member for personalized gift suggestions or use our digital kiosks for ideas.",
      "customer_locker_policy": "Lockers may be free or paid depending on the store location. Please check at the help desk for details.",
      "self_checkout_kiosks": "Self-checkout kiosks are available in most stores for faster and contactless billing.",
      "clearance_sale_preview": "Upcoming clearance sales are previewed on our website, app, or in-store flyers.",
      "first_time_shopper_offers": "Special offers are available for first-time shoppers. Ask at checkout or check our app for current promotions.",
      "combo_pack_sales": "Combo packs are available for many products and are clearly marked in-store.",
      "in_store_currency_exchange": "Currency exchange services are not typically available in-store.",
      "in_store_feedback_form": "Feedback forms are available at the customer service desk or via digital kiosks in-store.",
      "team_uniform_sales": "Team uniforms and group apparel can be purchased in-store or ordered at the customer service desk.",
      "office_essentials_sale": "Office essentials such as stationery, electronics, and furniture are available in the office supplies section.",
      "custom_gift_card_designs": "Customized gift card designs are available for special occasions. Ask at the gift card counter.",
      "whatsapp_receipt_option": "Receipts can be sent to your WhatsApp number upon request at checkout.",
      "weekly_deals_announcement": "Weekly deals are announced in-store, on our app, and via email newsletters.",
      "corporate_billing_option": "Corporate billing is supported in-store. Provide your business details at checkout for a GST invoice.",
      "plant_based_product_labeling": "Plant-based products are clearly labeled and often grouped in a dedicated section.",
      "old_clothes_donation_instore": "You can donate old clothes at designated donation bins or the customer service desk in-store.",
      "online_clearance_item_sales": "Clearance items are also available for purchase online in our clearance section.",
      "seasonal_store_map_availability": "Seasonal store maps highlighting festive sections and offers are available at the entrance and help desk.",
      "cashback_app_acceptance": "We accept popular cashback apps for in-store payments. Check with staff for supported apps.",
      "fragrance_testing_zone": "A fragrance testing zone is available in the beauty section of most stores.",
      "large_cart_availability": "Large shopping carts are available at the store entrance for your convenience.",
      "checkout_gift_card_option": "Gift cards can be purchased at checkout counters in-store.",
      "themed_sales_weeks": "Themed sales weeks are hosted in-store throughout the year, featuring special deals and displays.",
      "reusable_bag_sales": "Reusable shopping bags are available for purchase at checkout.",
      "local_artisan_product_availability": "Local artisan products are featured in dedicated sections in many stores.",
      "personal_pickup_reminders": "Request personal pickup reminders at checkout or via our app for your in-store orders.",
      "eco_coin_acceptance": "Eco-coins or green points can be redeemed in-store for discounts on eco-friendly products.",
      "no_bag_checkout_discount": "A discount may be offered if you skip a carry bag at checkout. Ask staff for details.",
      "store_safety_protocols": "Store safety protocols are displayed at the entrance and throughout the store for your awareness.",
      "item_hold_request": "You can request to hold items at the billing counter for a short period while you shop.",
      "store_camera_monitoring": "Store cameras are active 24/7 for security and safety.",
      "holiday_flash_checkout": "Flash checkout counters are set up during holidays for faster service.",
      "eco_friendly_alternatives": "Eco-friendly alternatives are available for many products and are clearly marked in-store.",
      "multiple_coupon_redemption": "Multiple coupons can be redeemed together in-store, subject to terms and conditions.",
      "store_to_car_delivery": "Store-to-car delivery is available at select locations. Request this service at checkout.",
      "in_store_food_court": "A food court or refreshment area is available in select stores.",
      "automated_billing_machine": "Automated bill machines are installed in many stores for quick and easy invoice printing.",
      "damaged_goods_report": "Report damaged goods at the customer service desk for immediate assistance.",
      "healthcare_worker_discount": "Discounts for healthcare workers are available in-store with valid ID proof.",
      "in_store_lucky_draw": "Lucky draws are held in-store during special events and sales. Participate at the event counter.",
      "bilingual_counter_assistance": "Bilingual staff are available at checkout counters to assist you in multiple languages.",
      "in_store_prepayment_option": "Prepayment for products is supported in-store for special orders and pre-bookings.",
      "gadget_preorder_instore": "Pre-order new gadgets in-store at the electronics section or customer service desk.",
      "store_flyer_collection": "Store flyers and brochures can be collected at the entrance or information desk.",
      "visually_impaired_voice_support": "Voice support for visually impaired customers is available via kiosks or by requesting staff assistance.",
      "gift_box_provision": "Gift boxes are available for purchase or complimentary with select gift items at the gift desk.",
       "real_time_stock_check": "You can check real-time stock availability in-store using our app, kiosks, or by asking staff.",
      "weekly_flyers_physical_copy": "Physical copies of weekly flyers are available at the store entrance and customer service desk.",
      "store_music_timing_adjustment": "Store music is adjusted based on the time of day and shopping hours for an optimal experience.",
      "wishlist_access_instore": "Access your wishlist in-store via our app or at digital kiosks when logged into your account.",
      "emergency_exit_visibility": "All emergency exits are clearly marked and visible throughout the store.",
      "store_safety_staff_presence": "Trained safety staff are present in-store during all operating hours.",
      "shopping_time_scheduling": "You can schedule a shopping time slot online or by calling the store, especially during peak periods.",
      "senior_discount_policy": "Senior citizen discounts are available in-store with valid ID. Ask at checkout for current offers.",
      "daily_promotions_announcement": "Daily promotions are announced at the store entrance and through in-store displays.",
      "giftcard_promocode_combination": "Gift cards and promo codes can usually be combined at checkout, unless otherwise specified in the offer terms.",
      "billing_counter_charging_points": "Charging points for mobile devices are available at select billing counters.",
      "post_purchase_price_adjustment": "Post-purchase price adjustments may be available within a specified period. Ask at the help desk for policy details.",
      "sms_deals_signup": "Sign up for in-store SMS deals at the customer service desk or via our app.",
      "hands_free_shopping_assistance": "Hands-free shopping assistance is available in select stores. Ask staff for help with this service.",
      "elderly_shopping_volunteers": "Volunteers or staff are available to assist elderly shoppers throughout the store.",
      "fragile_item_packaging": "Special packaging for fragile items is provided at checkout to ensure safe transport.",
      "store_product_expert_request": "Request a store product expert at the help desk or by asking any staff member.",
      "daily_trolley_sanitization": "Trolleys and baskets are sanitized daily for customer safety.",
      "store_announcement_system": "A public announcement system is used in-store for important updates and promotions.",
      "checkout_item_review": "You can submit an item review at checkout using digital kiosks or our app.",
      "in_store_referral_points": "Earn referral points in-store by referring friends at the help desk or via your account.",
      "centralized_billing_system": "A centralized billing system allows you to check out at any counter regardless of where you shopped in the store.",
      "return_online_orders_instore": "Online orders can be returned at our retail stores with the original receipt and packaging.",
      "express_billing_line": "Express billing lines are available for customers with a limited number of items.",
      "bill_splitting_option": "Bill splitting across multiple payment methods is supported at checkout.",
      "product_demo_scheduling": "Schedule a product demo in advance by booking online or at the customer service desk.",
      "kids_activity_zone_availability": "Kids' activity zones are available in select stores during weekends and holidays.",
      "daily_shelf_restocking": "Shelves are restocked daily to ensure product availability.",
      "festival_decoration_kit_sales": "Festival decoration kits are available for sale in-store during major festive seasons.",
      "lost_and_found_counter": "A lost & found counter is located at the customer service desk.",
      "estore_event_alert_signup": "Sign up for in-store event alerts via SMS, app, or at the help desk.",
      "product_qr_code_details": "QR codes are available on product tags for instant access to details via our app.",
      "instore_loyalty_point_earning": "Earn loyalty points on every in-store purchase by providing your membership details at checkout.",
      "student_discount_policy": "Student discounts are available in-store with valid student ID. Ask at checkout for eligibility.",
      "international_brand_availability": "A wide range of international brands are available in our stores, especially in fashion and electronics.",
      "store_layout_map_request": "Store layout maps are available at the entrance, kiosks, or customer service desk.",
      "bulk_order_service_availability": "Bulk order services are available in-store. Speak to a sales associate or visit the bulk order desk.",
      "upi_qr_payment_supported": "UPI QR payment is supported at all billing counters for quick and secure transactions.",
      "printed_catalog_pickup": "Printed catalogs can be picked up at the store entrance or customer service desk.",
      "doorstep_installation_service": "Doorstep installation is offered for select products. Book this service at checkout or with staff.",
      "gender_neutral_restroom_availability": "Gender-neutral restrooms are available in select stores. Ask staff for directions.",
      "queue_status_display": "Real-time queue status is displayed near billing counters and on digital screens.",
      "custom_wrapping_paper_request": "You can request custom wrapping paper for gifts at the gift desk or checkout.",
      "carbon_neutral_shopping_support": "We support carbon-neutral shopping through eco-friendly initiatives and offset programs.",
      "consumable_allergy_information": "Allergy information for consumable products is available on labels or by asking staff.",
      "guide_dog_policy": "Guide dogs and service animals are welcome in all our stores.",
      "loyalty_card_balance_preload": "Pre-load balance on your loyalty card at checkout or via your account online.",
      "quiet_shopping_hour_schedule": "Quiet shopping hours are scheduled in select stores. Check with your local store for timings.",
      "feedback_kiosk_tablet_option": "Leave feedback through tablet kiosks located near exits or at the help desk.",
      "vending_machine_zone_location": "Vending machine zones are located near the entrance or food court in select stores.",
      "purchase_trend_display": "Purchase trends and popular products are displayed on digital screens in-store.",
      "emergency_medical_support": "Emergency medical support is available in-store. Contact staff immediately if needed.",
      "weekend_flash_deals_info": "Weekend flash deals are announced at the entrance and via app notifications.",
      "app_barcode_scan_support": "Our app supports barcode scanning for price checks and product details in-store.",
      "group_shopping_session_booking": "Book a group shopping session in advance by calling the store or online.",
      "holiday_theme_store_decor": "Stores feature holiday-themed decor during major festivals and seasons.",
      "exclusive_product_tagging": "Exclusive products are specially tagged and highlighted in-store.",
      "eco_shopping_tips_display": "Eco-friendly shopping tips are displayed on digital screens and posters throughout the store.",
       "weekend_staffing_policy": "We increase staff during weekends and peak hours to ensure smooth shopping and customer support.",
      "trending_item_display": "Trending items are displayed in dedicated sections and highlighted on digital screens in-store.",
      "closing_time_notification": "Shoppers are notified about closing time through in-store announcements and digital displays.",
      "water_refill_station_location": "Water refill stations are available near the food court or restrooms in select stores.",
      "instore_health_checkup_services": "Health checkup services are offered in select stores during special events. Ask at the help desk for availability.",
      "donation_bin_location": "Donation bins are located near the entrance or customer service desk for your convenience.",
      "pet_supply_availability": "Pet supplies including food, toys, and accessories are available in the pet care section of our stores.",
      "online_order_instore_pickup": "In-store pickup is available for online orders. Choose this option at checkout and collect from the pickup counter.",
      "customer_desk_callback_request": "Request a callback from the customer desk by leaving your details at the help desk or via our app.",
      "battery_recycling_points": "Battery recycling points are available in-store, usually near the entrance or electronics section.",
      "multilingual_signage_availability": "Multilingual signs are displayed throughout the store for easy navigation.",
      "express_delivery_instore": "Express delivery is available for select in-store purchases. Ask at checkout for eligibility and charges.",
      "offline_loyalty_program_signup": "Sign up for our loyalty program offline at the customer service desk in any store.",
      "motion_sensor_entry_doors": "Most store entrances are equipped with motion-sensor automatic doors.",
      "scan_and_bag_option": "Scan and bag as you shop is available in select stores using our app or smart carts.",
      "dedicated_vegan_section": "A dedicated vegan section is available in our food and grocery aisles.",
      "green_product_labeling": "Green and eco-friendly products are labeled with special tags and signage.",
      "interactive_display_units": "Interactive display units are installed in various departments for product info and offers.",
      "delivery_cash_tip_option": "You can tip delivery personnel in cash upon receiving your order.",
      "bulk_coupon_book_acceptance": "Bulk coupon books are accepted in-store for eligible products, subject to terms and conditions.",
      "whatsapp_ordering_option": "Orders can be placed via WhatsApp for select products and stores. Check our website for the number.",
      "personalized_shopping_experience": "Personalized shopping experiences are available by appointment or on request at the help desk.",
      "pen_request_billing_desk": "You can borrow a pen at the billing desk if needed.",
      "auto_hand_sanitizer_availability": "Automatic hand sanitizer dispensers are available throughout the store.",
      "air_conditioning_status": "Our stores are air-conditioned year-round for your comfort.",
      "printed_coupon_availability": "Printed coupons are available at the entrance, customer service desk, or during special promotions.",
      "product_eco_label_display": "Eco-labels are displayed on products that meet our sustainability standards.",
      "entry_floor_guide_availability": "Floor guides are available at the store entrance to help you navigate.",
      "instore_wifi_coupon_request": "Request Wi-Fi coupons at the help desk or via SMS at select stores.",
      "smart_cart_assistance_button": "Smart carts are equipped with an assistance button to call for help if needed.",
      "background_music_availability": "Background music is played in all departments to enhance your shopping experience.",
      "instore_tasting_sample_offer": "Tasting samples are offered in select departments, especially during weekends and launches.",
      "store_promotion_preview_online": "Preview store promotions online or in the app before visiting.",
      "instore_help_app_button": "Use the help button in our app for in-store assistance or to call staff.",
      "reward_balance_instore_check": "Check your reward or loyalty point balance at checkout or via digital kiosks.",
      "event_merchandise_sales": "Event-specific merchandise is available in-store during festivals and special events.",
      "price_match_guarantee_policy": "We offer a price match guarantee on select products. Ask staff for terms and eligible brands.",
      "mobile_charging_station_availability": "Mobile device charging stations are available in most stores near the lounge or customer service area.",
      "instore_product_recommendation": "Get personalized product recommendations from staff or digital kiosks in-store.",
      "digital_menu_foodcourt": "Digital menus are used in the food court for easy browsing and ordering.",
      "bill_donation_option": "You can round up your bill or donate a portion to charity at checkout.",
      "waiting_lounge_area_availability": "A lounge or waiting area is available near the entrance or billing counters.",
      "instore_electronics_testing": "Test electronics in-store at demo zones or with staff assistance.",
      "seasonal_shopping_checklist": "Seasonal shopping checklists are available at the entrance or on our app.",
      "instore_birthday_surprises": "Birthday surprises and perks are available for loyalty members. Register your birthday in your account.",
      "receipt_donation_optin": "Opt in to donate your receipt value to charity at checkout or via your account.",
      "instore_product_rating_display": "Product ratings and reviews are displayed on digital screens and tags in-store.",
      "family_shopping_account_option": "Create a family shopping account for shared benefits and tracking. Sign up at the help desk.",
      "flash_deal_alerts_app": "Enable flash deal alerts in our app to receive notifications about in-store offers.",
      "kids_trolley_availability": "Kids’ trolleys are available at the entrance for a fun shopping experience.",
      "anonymous_behavior_feedback": "Report rude or inappropriate behavior anonymously via our feedback kiosks or app.",
      "local_farm_goods_promotion": "Local farm goods are promoted in-store with special displays and events.",
      "product_tester_signup": "Sign up to become a product tester at the customer service desk or via our app.",
      "kids_play_corner_location": "Kids’ play corners are located near the family section or café in select stores.",
      "low_stock_alert_request": "Request low-stock alerts for your favorite items at the help desk or in the app.",
      "pet_policy_during_festival": "Pet policies during festivals may vary. Check with your local store for current guidelines.",
      "group_billing_option": "Group billing is available for families or groups shopping together. Ask at checkout.",
      "entry_smart_price_scanner": "Smart price scanners are located near the entrance for quick price checks.",
      "last_minute_gift_sales": "Last-minute gifts are available at dedicated counters near the entrance or billing area.",
      "change_delivery_slot": "You can change your delivery slot after placing the order by contacting customer service or via your account.",
      "same_day_online_pickup": "Same-day pickup for online orders is available for select products and stores.",
      "loyalty_points_sales_validity": "Loyalty points can usually be redeemed during sales unless stated otherwise in the offer terms.",
      "instore_flash_mob_events": "Flash mobs and surprise events are occasionally organized in-store during special campaigns.",
      "self_service_kiosk_shopping": "Shop and check out using self-service kiosks available in many departments.",
      "used_bag_recycling_acceptance": "Used bags can be dropped off for recycling at designated points in-store.",
      "national_holiday_open_status": "Most stores remain open during national holidays, but hours may vary. Check online or call ahead.",
      "refill_pack_availability": "Refill packs for popular products are available in-store in the relevant sections.",
      "drive_in_shopping_option": "Drive-in shopping and pickup are available at select locations. Check with your local store.",
      "refurbished_item_availability": "Refurbished items are available in select stores and are clearly labeled.",
      "app_deal_preview": "Preview upcoming deals in the app before visiting the store.",
      "corporate_gift_options": "Corporate gift options are available in-store. Ask at the gift desk or customer service.",
      "gender_specific_trial_rooms": "Gender-specific trial rooms are available in the apparel section.",
      "product_suggestion_submission": "Submit product suggestions at the feedback kiosk or via our app.",
      "instore_product_survey": "Participate in in-store product surveys at digital kiosks or during special events.",
      "pet_friendly_store_status": "Our stores are generally pet-friendly year-round, but please check local guidelines for any restrictions.",
      "qr_coupon_scan_feature": "Scan QR codes in-store to receive instant coupons and offers.",
      "sign_language_staff_training": "Many staff members are trained in basic sign language to assist hearing-impaired customers.",
      "biodegradable_bag_availability": "Biodegradable carry bags are available for purchase at checkout.",
      "satisfaction_rating_kiosk": "Satisfaction rating kiosks are located near the exit for quick feedback.",
      "bluetooth_audio_test_availability": "Bluetooth audio test facilities are available in the electronics section for compatible products.",
      "allergen_free_guide": "Allergen-free product guides are available at the customer service desk or on our app.",
        "custom_embroidery_service": "Custom embroidery services are available in select stores. Ask at the tailor or customization counter for details.",
      "multipack_discount_info": "Multipack discounts are offered on select products and are clearly marked in-store.",
      "expired_product_reporting": "Report expired products found in-store to any staff member or at the customer service desk.",
      "contactless_checkout_lane": "Contactless checkout lanes are available in many stores for quick and safe billing.",
      "seasonal_shopping_festival": "Seasonal shopping festivals are organized with special deals and events. Check our calendar or ask staff for upcoming dates.",
      "instore_job_application": "Apply for jobs in-store at the customer service desk or via our careers page online.",
      "electric_scooter_policy": "Electric scooters are generally not allowed inside for safety reasons. Please park them at designated areas outside.",
      "cart_sanitizing_wipe_availability": "Sanitizing wipes for carts are available at the store entrance or near cart stations.",
      "digital_queue_system_availability": "A digital queue system is in place in most stores. Check your position on digital screens or via our app.",
      "kids_emergency_wristbands": "Emergency contact wristbands for kids are available at the entrance or customer service desk.",
      "printed_invoice_availability": "Printed invoices are provided at checkout for all in-store purchases.",
      "eco_friendly_packaging_option": "Eco-friendly packaging is available for most items. Request this option at checkout.",
      "advance_order_product_launch": "Advance orders for upcoming product launches can be placed at the electronics or customer service desk.",
      "handmade_item_section": "A special section for handmade items is available in select stores, featuring local artisans.",
      "reusable_container_policy": "Reusable containers are welcome for select bulk and zero-waste items. Please ensure they are clean.",
      "midnight_sale_schedule": "Midnight sales are held during major shopping festivals. Check our event calendar for dates.",
      "emergency_response_staff_training": "All staff are trained in emergency response and safety protocols.",
      "costume_rental_availability": "Costume rental services are available in select stores. Inquire at the customer service desk.",
      "dressing_room_size_chart": "Size charts are displayed in all dressing rooms for your convenience.",
      "purchase_history_instore_access": "Access your purchase history in-store via your account at digital kiosks or the help desk.",
      "customer_lucky_draw_events": "Lucky draw events are held during special promotions. Participate by shopping or registering at the event counter.",
      "unboxing_station_availability": "Unboxing stations are available near the electronics and gifting sections for immediate product checks.",
      "free_sampling_day_schedule": "Free sampling days are scheduled regularly. Check our app or in-store flyers for upcoming dates.",
      "fitting_room_slot_booking": "Book fitting room slots in advance at the help desk or via our app in select stores.",
      "plant_based_household_item_sales": "Plant-based household items are available in the eco and cleaning sections.",
      "kiosk_shopping_list_printing": "Print your shopping list from digital kiosks located throughout the store.",
      "buy_now_pay_later_availability": "Buy-now-pay-later options are available at checkout for eligible purchases.",
      "essential_vending_machine_location": "Vending machines for essentials are located near the entrance or restrooms.",
      "packaging_free_option_request": "Request packaging-free options for select items at the relevant counter or bulk section.",
      "digital_loyalty_stamp_program": "Our digital loyalty stamp program is available via the app or at checkout.",
      "happy_hour_sale_schedule": "Happy hour sales are announced in-store and on our app. Check for daily timings.",
      "custom_weighing_container_usage": "You can use your own container for weighing in the bulk section. Please have it pre-weighed by staff.",
      "influencer_zone_location": "Influencer zones for content creation are available in select stores. Ask staff for location and guidelines.",
      "walkin_interview_schedule": "Walk-in interview days are scheduled regularly. Check our careers page or ask at the help desk for dates.",
      "emi_option_checkout": "EMI options are available at checkout for eligible products. Ask staff for details and plans.",
      "disposable_glove_availability": "Disposable gloves are available at the entrance or customer service desk upon request.",
      "focus_group_signup": "Sign up for focus group programs at the help desk or via our app.",
      "soldout_item_waitlist": "Join a waitlist for sold-out items at the customer service desk or in the app.",
      "touchfree_screen_availability": "Touch-free interactive screens are available in select stores for a hygienic experience.",
      "reusable_kitchen_item_sales": "Reusable kitchen items are available in the home and kitchen section.",
      "accessibility_all_abilities": "Our stores are accessible for all abilities, including ramps, elevators, and accessible restrooms.",
      "eco_product_shelf_location": "Eco-product shelves are located in the eco-friendly or green section of the store.",
      "digital_ingredient_info": "View ingredient information digitally by scanning product barcodes or using our app.",
      "sms_receipt_option": "Payment receipts can be sent to your mobile via SMS upon request at checkout.",
      "walkin_trial_day_schedule": "Walk-in product trial days are held regularly. Check our event calendar or ask staff for details.",
      "trial_room_reservation": "Reserve a trial room before visiting by calling the store or booking via our app.",
      "product_comparison_tool": "Product comparison tools are available on digital kiosks and our app in-store.",
      "loyalty_point_charity_donation": "Donate your loyalty points to charity at the help desk or via your loyalty account.",
      "birthday_discount_policy": "Birthday discounts are available for loyalty members. Register your birthday in your profile to receive offers.",
      "weekly_clearance_rack_info": "Weekly clearance racks are updated every week and located near the entrance or deals section.",
      "mobile_checkout_cart_availability": "Mobile checkout carts are available in select stores for a seamless self-checkout experience.",
      "ar_fashion_preview": "Preview fashion styles in AR using our app or in-store digital mirrors.",
      "refurbished_electronics_sales": "Refurbished electronics are available in select stores and are clearly labeled.",
      "store_power_backup_status": "All stores are equipped with power backup to ensure uninterrupted shopping.",
      "instore_tailor_availability": "In-house tailoring and alteration services are available in many stores. Ask at the fashion desk.",
      "express_giftwrap_booth": "Express gift-wrapping booths are available near the gift section or checkout.",
      "ethical_product_availability": "Ethically sourced goods are available and labeled in dedicated store sections.",
      "ethical_filter_screen_option": "Filter products by ethical criteria using our digital kiosks or app in-store.",
      "digital_expiry_display": "Expiry dates are displayed digitally on screens or by scanning product barcodes.",
      "mothers_lounge_availability": "A mother’s lounge is available in select stores for nursing and baby care.",
      "screen_product_query_option": "Ask product-related questions via interactive screens in-store for instant answers.",
      "rfid_basket_availability": "RFID-enabled baskets are available in select stores for faster checkout and tracking.",
      "charity_shopping_event": "Charity shopping weekends are organized regularly. Check our event calendar for upcoming dates.",
      "gift_exchange_without_bill": "Gift exchanges without a bill may be allowed at store discretion. Valid ID and product details may be required.",
      "family_shopping_hours": "Family-only shopping hours are scheduled during special events. Check with your local store for timings.",
      "digital_lighting_issue_reporting": "Report lighting issues digitally via our app or at in-store kiosks.",
      "preowned_clothing_sales": "Pre-owned clothing is available in select stores and clearly labeled in the relevant section.",
      "digital_lost_item_board": "A digital lost item board is available at the customer service desk or on our app.",
      "fashion_styling_session_schedule": "Fashion styling sessions are scheduled regularly. Book at the fashion desk or via our app.",
      "intercom_staff_request": "Request staff assistance via intercoms located throughout the store.",
      "store_merchandise_sales": "Store-branded merchandise is available for sale in the gifts or apparel section.",
      "instore_theme_voting": "Vote on the next in-store theme using our app or at digital kiosks.",
      "first_aid_kit_location": "First-aid kits are publicly accessible at the customer service desk and key locations throughout the store.",
      "zero_waste_shopping_support": "We support zero-waste shopping with bulk bins, reusable options, and minimal packaging.",
      "restock_alerts": "Sign up for restock alerts at the help desk or via our app to be notified when items are back in stock.",
      "nutritionist_food_section_availability": "A nutritionist is available in the food section during select hours for advice and consultations.",
      "retail_ambassador_program": "Join our retail ambassador program by applying at the customer service desk or online.",
      "customer_appreciation_event": "Customer appreciation events are hosted regularly with special perks and offers. Check our event calendar.",
      "loyalty_card_replacement": "Replace your loyalty card in-store at the customer service desk with valid ID.",
      "live_product_demo_availability": "Live product demos are conducted daily in select departments. Check the schedule or ask staff.",
      "out_of_stock_restock_request": "Request restock for out-of-stock items at the help desk or via our app.",
      "gift_card_customization": "Gift card customization is available at the gift card counter for special occasions.",
      "senior_discount_day": "Special senior citizen discount days are held weekly. Ask at the help desk for the schedule.",
      "clearance_item_return_policy": "Clearance items can usually be returned within a limited period unless marked final sale.",
      "wardrobe_consultation_availability": "Wardrobe consultations are available with our in-store stylists by appointment.",
      "electronics_recycling_bin_location": "Electronics recycling bins are located near the electronics section or store entrance.",
      "personal_shopping_schedule": "Schedule personal shopping assistance in advance at the help desk or via our app.",
      "detergent_refill_station": "Detergent refill stations are available in the cleaning supplies section of select stores.",
      "free_health_checkup_availability": "Free health checkups are available during special wellness days. Check our event calendar or ask staff.",
      "shopping_tips_from_staff": "Ask any staff member for shopping tips or product recommendations during your visit.",
      "product_testing_program": "Join our product testing program by signing up at the customer service desk or online.",
      "student_discount_availability": "Discounts for students are available in-store with valid student ID.",
      "travel_size_essential_availability": "Travel-size essentials are available in the personal care and travel section.",
      "holiday_catalog_availability": "Holiday season catalogs are available at the entrance and customer service desk.",
      "staff_pick_display": "Staff recommendations are displayed in-store on special racks and digital screens.",
      "try_before_buy_service": "Try-before-you-buy services are available for select products. Ask staff for details.",
      "car_loading_assistance": "Staff assistance for loading items into your car is available upon request at checkout.",
      "kids_art_event_schedule": "Art and craft events for kids are scheduled regularly. Check our events calendar or ask staff.",
      "electronic_price_tag_usage": "Electronic price tags are used throughout the store for real-time pricing updates.",
      "spending_tracker_app": "Track your in-store and online spending using our mobile app's spending tracker feature.",
      "budget_shopping_guide": "Budget shopping guides are available at the entrance and on our app.",
      "store_cleanliness_feedback": "Submit store cleanliness feedback at the help desk, kiosks, or via our app.",
      "monthly_new_arrival_alerts": "Sign up for monthly new arrival alerts via SMS, email, or our app.",
      "smart_shopping_assistant_availability": "Smart shopping assistants are available via kiosks or our app in select stores.",
      "prebook_item_before_launch": "Pre-book items before launch at the customer service desk or via our app.",
      "health_sample_counter": "Health product sample counters are available in the wellness and pharmacy sections.",
      "instore_yoga_session_schedule": "In-store yoga sessions are scheduled during wellness events. Check our calendar for details.",
      "powerbank_rental_availability": "Power bank rental stations are available near the entrance or customer service area.",
      "allergy_filter_feature": "Filter items by allergy concerns using our app or digital kiosks.",
      "diy_kit_availability": "Do-it-yourself kits are available in the crafts and home improvement sections.",
      "whatsapp_store_deal_alerts": "Subscribe to WhatsApp alerts for store deals and promotions at the help desk or online.",
      "app_flash_sale_schedule": "Flash sales are announced in the app with exclusive deals for app users.",
      "price_drop_alert_feature": "Set price drop alerts for your favorite items in the app or at digital kiosks.",
      "virtual_trial_room_availability": "Virtual trial rooms are available in select stores for digital fitting experiences.",
      "printed_store_map_request": "Request a printed store map at the entrance or customer service desk.",
      "social_cause_donation_option": "Donate to social causes while shopping at checkout or via our app.",
      "cruelty_free_makeup_availability": "Cruelty-free makeup is available in the beauty section and labeled accordingly.",
      "instore_voice_command_support": "Voice command support is available on select kiosks for hands-free assistance.",
      "multi_language_display_support": "Multi-language display support is available on digital screens and kiosks.",
      "child_safe_cart_design": "All shopping carts are designed with child safety features.",
      "trending_product_display": "Trending products are featured in dedicated displays and on digital screens in-store.",
      "mobile_locker_storage_service": "Mobile locker storage is available in select stores for your personal items.",
      "plastic_bottle_recycling_bin": "Plastic bottle recycling bins are located near the entrance or food court.",
      "store_urgent_contact_number": "For urgent complaints, call the number displayed at the entrance or on your receipt.",
      "employee_recognition_display": "Employee recognition programs and displays are featured in-store to celebrate outstanding staff.",
      "grocery_recipe_display": "Product recipes are displayed near groceries and on digital screens in the food section.",
      "scan_and_skip_checkout_option": "Scan and skip checkout lines using our app or smart carts in select stores.",
      "quiet_hour_neurodivergent_customers": "Quiet shopping hours for neurodivergent customers are scheduled weekly. Check with your local store for timings.",
      "link_multiple_loyalty_accounts": "Link multiple loyalty accounts at the customer service desk or via your account online.",
      "clothing_alteration_service": "Clothing alteration services are available in-store at the tailor or fashion desk.",
      "digital_scavenger_hunt_event": "Digital scavenger hunts are organized during special events. Join via our app or at the event desk.",
      "referral_bonus_loyalty_points": "Earn bonus loyalty points for successful referrals. Register your referral at the help desk or online.",
      "store_theme_merchandise": "Store-themed merchandise is available for sale in the gifts or apparel section.",
      "delivery_driver_background_check": "All delivery drivers undergo thorough background checks for your safety.",
      "single_item_fast_checkout": "Fast checkout counters for single-item purchases are available at the entrance.",
      "store_newsletter_subscription": "Subscribe to our store newsletter at the help desk or via our website.",
      "eco_tips_display": "Eco-friendly shopping tips are displayed on digital screens and posters throughout the store.",
      "braille_signage_availability": "Braille signage is available in key areas of the store for visually impaired customers.",
      "party_supply_rental": "Party supply rental services are available in select stores. Ask at the customer service desk.",
      "staff_rating_feedback_tool": "Rate staff service at feedback kiosks or in our app after your visit.",
      "store_exclusive_item_availability": "Store-exclusive items are available in dedicated sections and clearly marked.",
      "group_shopping_discount_policy": "Group shopping discounts are offered for large groups or families. Ask at checkout for eligibility.",
      "misplaced_bill_reporting": "Report misplaced bills at the customer service desk for reissue or assistance.",
      "pdf_catalog_availability": "PDF catalogs are available for download from our website or app.",
      "climate_neutral_product_sales": "Climate-neutral products are available and labeled in the eco-friendly section.",
      "prepaid_card_usage_policy": "Prepaid cards are accepted for in-store purchases at all billing counters.",
      "waiting_zone_charging_station": "Waiting zones with charging stations are available near the entrance or lounge area.",
      "zero_interest_emi_availability": "Zero-interest EMI plans are available on select products. Ask staff for current offers.",
      "allergy_info_barcode_scan": "Scan product barcodes using our app to access allergy information instantly.",
      "travel_theme_event_schedule": "Travel-themed shopping events are held seasonally. Check our event calendar or ask staff.",
      "subscription_box_gifting_option": "Gift a subscription box by purchasing at the customer service desk or online.",
      "smart_home_device_availability": "Smart home devices are available in the electronics and home automation section.",
      "parking_reservation_availability": "Reserve parking in advance at select stores via our app or by calling ahead.",
      "cultural_sensitivity_staff_training": "All staff receive cultural sensitivity training to ensure an inclusive shopping environment.",
      "item_donation_program": "Donate items through our in-store donation program at designated bins or the help desk.",
      "product_sustainability_score": "Product sustainability scores are displayed on tags and digital screens for select items.",
      "store_social_media_links": "Follow us on social media using the links provided at the entrance, on receipts, or our website.",
      "team_shopping_challenge_event": "Team shopping challenges are organized during special events. Register at the event desk or via our app.",
      "free_water_refill_location": "Free water refill points are available near the food court or restrooms.",
      "digital_queue_position_display": "View your queue position on digital screens or in our app while waiting to check out.",
      "festival_theme_decor_section": "Festival-themed decor sections are set up during major holidays and events.",
      "sms_customer_service_request": "Request customer service via SMS using the number displayed in-store or on your receipt.",
      "luxury_gift_wrapping_service": "Luxury gift wrapping is available at the gift desk for an additional fee.",
      "warranty_card_printing_option": "Warranty cards can be printed in-store at the customer service or electronics desk.",
      "refillable_stationery_sales": "Refillable stationery is available in the office supplies section.",
      "language_interpretation_service": "Language interpretation assistance is available at the help desk or via our app.",
      "kids_product_review_program": "Kids can join our product review panel by signing up at the kids’ section or online.",
      "fashion_doorstep_trial": "Doorstep trial for fashion items is available in select locations. Book via our app or at the fashion desk.",
      "instore_video_testimonial_booth": "Leave a video testimonial at our in-store booth, located near the exit or customer service area.",
      "aisle_price_scanner_availability": "Price scanners are available at the end of each aisle for quick price checks.",
      "community_board_display": "Community bulletin boards are located near the entrance or café for local news and events.",
      "product_tutorial_demonstration": "Product tutorials and demonstrations are held in-store regularly. Check the schedule or ask staff.",
      "local_farmer_product_support": "We support local farmers by featuring their produce in dedicated sections and promotions.",
      "express_billing_counter_info": "Express billing counters are available for quick checkout with limited items.",
      "self_checkout_return_policy": "Returns at self-checkout stations are supported for eligible items. Ask staff for assistance if needed.",
      "large_item_return_pickup": "Free pickup for large returns can be scheduled at the help desk or via our app."
    }

# %%
# Build chatbot dataset from Excel and intent_responses
chat_data = []
for _, row in df.iterrows():
    intent = row["Intent"].strip().lower()
    answer = intent_responses.get(intent, "Sorry, I don’t have an answer for that intent.")
    chat_data.append({
        "question": row["Question"].strip().lower(),
        "intent": intent,
        "answer": answer
    })

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Extract questions for vectorization
questions = [item['question'] for item in chat_data]
vectorizer = TfidfVectorizer()
question_vectors = vectorizer.fit_transform(questions)

# Chatbot function
def chatbot_response(user_input):
    user_input = user_input.lower()
    user_vector = vectorizer.transform([user_input])

    similarity = cosine_similarity(user_vector, question_vectors)
    idx = similarity.argmax()
    score = similarity[0][idx]

    if score > 0.3:
        response = chat_data[idx]
        return f"Bot: {response['answer']} (Intent: {response['intent']})"
    else:
        return "Bot: Sorry, I didn't understand that. Can you rephrase?"

# %%
print("Welcome to the chatbot! Type 'exit' to quit.")
while True:
    user_input = input("You: ")
    if user_input.lower() == 'exit':
        break
    print(chatbot_response(user_input))
# Out:
# Welcome to the chatbot! Type 'exit' to quit.
# You:  Do you offer gift-wrapping for in-store purchases?
# Bot: Gift-wrapping is available for in-store purchases at the gift desk or checkout. (Intent: in_store_gift_wrapping)
# You:  Do you offer gift-wrapping for in-store purchases?
# Bot: Gift-wrapping is available for in-store purchases at the gift desk or checkout. (Intent: in_store_gift_wrapping)
